# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df_AAL = pd.read_csv('data_nasdaq/data_nasdaq_csv/AAL.csv')
df_AAL
# Out:
#             Date        Low       Open    Volume       High      Close  \
# 0     27-09-2005  19.100000  21.049999    961200  21.400000  19.299999
# 1     28-09-2005  19.200001  19.299999   5747900  20.530001  20.500000
# 2     29-09-2005  20.100000  20.400000   1078200  20.580000  20.209999
# 3     30-09-2005  20.180000  20.260000   3123300  21.049999  21.010000
# 4     03-10-2005  20.900000  20.900000   1057900  21.750000  21.500000
# ...          ...        ...        ...       ...        ...        ...
# 4328  06-12-2022  14.000000  14.140000  20781500  14.340000  14.330000
# 4329  07-12-2022  13.530000  14.240000  28161400  14.240000  13.550000
# 4330  08-12-2022  13.380000  13.650000  25300900  13.800000  13.600000
# 4331  09-12-2022  13.420000  13.520000  18489800  13.660000  13.530000
# 4332  12-12-2022  13.450000  13.490000   8048550  13.930000  13.915000
#
#       Adjusted Close
# 0          18.194910
# 1          19.326204
# 2          19.052805
# 3          19.807001
# 4          20.268940
# ...              ...
# 4328       14.330000
# 4329       13.550000
# 4330       13.600000
# 4331       13.530000
# 4332       13.915000
#
# [4333 rows x 7 columns]

# %%
df = df_AAL.drop(columns = ['Low', 'High', 'Open', 'Adjusted Close', 'Volume'], axis = 1)

# %%
import datetime
def str_to_datetime(s):
    try:
        split = s.split('-')
        day, month, year = int(split[0]), int(split[1]), int(split[2])
        return datetime.datetime(day=day, month=month, year=year)
    except ValueError:
        print(f"Invalid date string: {s}")
        return None
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# 0      2005-09-27
# 1      2005-09-28
# 2      2005-09-29
# 3      2005-09-30
# 4      2005-10-03
#           ...
# 4328   2022-12-06
# 4329   2022-12-07
# 4330   2022-12-08
# 4331   2022-12-09
# 4332   2022-12-12
# Name: Date, Length: 4333, dtype: datetime64[ns]

# %%
# Set date as the index
df.index = df.pop('Date')

# %%
plt.rcParams['figure.figsize'] = (18, 12)

def price(x):
    """
    format the coords message box
    :param x: data to be formatted
    :return: formatted data
    """
    return '$%1.2f' % x

fig, ax = plt.subplots()
ax.plot(df.index, df['Close'], '#0A7388')
ax.format_ydata = price
# Add labels
plt.ylabel("Price USD")
plt.xlabel("Date")

plt.show()

# %%
### Split the dataset into time windows to get data samples.

# df = data_appl
X_data = []
y_data = []
dates = []
window_size = 30 # Time window for data feature (size of 'number of days') to learn.

# Only get the open price (index 2 in the data frame)
for i in range(1, len(df) - window_size - 1):
    first = df.iloc[i, 0]
    data_feature = []
    data_label = []
    
    # Get a window_size time frame for data feature
    for j in range(window_size):
        data_feature.append(df.iloc[i + j, 0])
        
    # Next value is the label (price of the next day) to be predicted
    data_label.append(df.iloc[i + window_size, 0])
    
    # Append new data sample (feature and label) to X_data and y_data
    X_data.append(np.array(data_feature).reshape(window_size, 1))
    y_data.append(np.array(data_label))
    dates.append(df.iloc[i + window_size, :].name)

# %%
len(X_data), len(y_data), len(dates)
# Out:
# (4301, 4301, 4301)

# %%
from data_nasdaq import data_preprocessing as pp
X_train_1, y_train_1, X_val_1, y_val_1, X_test_1, y_test_1, train_dates, val_dates, test_dates = pp.split_dataset(X_data, y_data, dates)

# %%
# Visualize the training, validation and test set
fig, ax = plt.subplots(figsize = (16,8))
df_plot = df['Close']
df_plot = df_plot.reset_index(drop=False)
plt.plot(train_dates, y_train_1)
plt.plot(val_dates, y_val_1)
plt.plot(test_dates, y_test_1)
plt.xlabel('Year')
plt.ylabel('Close price in $')
plt.legend(['Train', 'Validation', 'Test'])

# Add vertical lines to separate training, validation, and test sets
plt.axvline(x=train_dates[-1], color='k', linestyle='--')
plt.axvline(x=val_dates[-1], color='k', linestyle='--')

plt.show()

# %%
# Normalize data
X_train_norm, y_train_norm = pp.normalize_data(X_train_1, y_train_1)
X_val_norm, y_val_norm = pp.normalize_data(X_val_1, y_val_1)
X_test_norm, y_test_norm = pp.normalize_data(X_test_1, y_test_1)

# %%
### Create and train the model

# Import libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, LSTM, Dropout, Activation

# Build the model architecture
model = Sequential()
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(window_size, 1), padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1)) # By default: activation='linear', i.e., passing through f(x) = x

# Compile and train the model with Mean Squared Error loss function
model.compile(optimizer= Adam(learning_rate=0.001), 
              loss='mse', 
              metrics=['mean_absolute_error'])
model_training = model.fit(X_train_norm, y_train_norm, validation_data=(X_val_norm,y_val_norm), epochs=50, batch_size=32)
# Out:
# 2023-05-12 21:12:56.950118: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 86/86 [==============================] - 3s 13ms/step - loss: 0.0995 - mean_absolute_error: 0.2387 - val_loss: 0.0395 - val_mean_absolute_error: 0.1465
# Epoch 2/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0329 - mean_absolute_error: 0.1331 - val_loss: 0.0274 - val_mean_absolute_error: 0.1218
# Epoch 3/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0269 - mean_absolute_error: 0.1190 - val_loss: 0.0258 - val_mean_absolute_error: 0.1151
# Epoch 4/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0261 - mean_absolute_error: 0.1176 - val_loss: 0.0246 - val_mean_absolute_error: 0.1145
# Epoch 5/50
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0253 - mean_absolute_error: 0.1159 - val_loss: 0.0242 - val_mean_absolute_error: 0.1113
# Epoch 6/50
# 86/86 [==============================] - 0s 5ms/step - loss: 0.0256 - mean_absolute_error: 0.1171 - val_loss: 0.0267 - val_mean_absolute_error: 0.1210
# Epoch 7/50
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0243 - mean_absolute_error: 0.1139 - val_loss: 0.0250 - val_mean_absolute_error: 0.1151
# Epoch 8/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0244 - mean_absolute_error: 0.1150 - val_loss: 0.0241 - val_mean_absolute_error: 0.1136
# Epoch 9/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0241 - mean_absolute_error: 0.1132 - val_loss: 0.0255 - val_mean_absolute_error: 0.1180
# Epoch 10/50
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0238 - mean_absolute_error: 0.1129 - val_loss: 0.0239 - val_mean_absolute_error: 0.1133
# Epoch 11/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0229 - mean_absolute_error: 0.1105 - val_loss: 0.0249 - val_mean_absolute_error: 0.1143
# Epoch 12/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0229 - mean_absolute_error: 0.1106 - val_loss: 0.0236 - val_mean_absolute_error: 0.1124
# Epoch 13/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0226 - mean_absolute_error: 0.1115 - val_loss: 0.0230 - val_mean_absolute_error: 0.1092
# Epoch 14/50
# 86/86 [==============================] - 1s 17ms/step - loss: 0.0220 - mean_absolute_error: 0.1087 - val_loss: 0.0244 - val_mean_absolute_error: 0.1150
# Epoch 15/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0213 - mean_absolute_error: 0.1074 - val_loss: 0.0252 - val_mean_absolute_error: 0.1159
# Epoch 16/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0217 - mean_absolute_error: 0.1098 - val_loss: 0.0239 - val_mean_absolute_error: 0.1116
# Epoch 17/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0213 - mean_absolute_error: 0.1075 - val_loss: 0.0305 - val_mean_absolute_error: 0.1326
# Epoch 18/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0204 - mean_absolute_error: 0.1055 - val_loss: 0.0241 - val_mean_absolute_error: 0.1136
# Epoch 19/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0200 - mean_absolute_error: 0.1048 - val_loss: 0.0242 - val_mean_absolute_error: 0.1134
# Epoch 20/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0203 - mean_absolute_error: 0.1060 - val_loss: 0.0254 - val_mean_absolute_error: 0.1177
# Epoch 21/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0188 - mean_absolute_error: 0.1019 - val_loss: 0.0248 - val_mean_absolute_error: 0.1131
# Epoch 22/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0179 - mean_absolute_error: 0.0998 - val_loss: 0.0302 - val_mean_absolute_error: 0.1304
# Epoch 23/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0180 - mean_absolute_error: 0.1006 - val_loss: 0.0259 - val_mean_absolute_error: 0.1165
# Epoch 24/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0172 - mean_absolute_error: 0.0993 - val_loss: 0.0259 - val_mean_absolute_error: 0.1182
# Epoch 25/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0183 - mean_absolute_error: 0.1020 - val_loss: 0.0300 - val_mean_absolute_error: 0.1302
# Epoch 26/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0169 - mean_absolute_error: 0.0978 - val_loss: 0.0266 - val_mean_absolute_error: 0.1182
# Epoch 27/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0159 - mean_absolute_error: 0.0950 - val_loss: 0.0282 - val_mean_absolute_error: 0.1224
# Epoch 28/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0152 - mean_absolute_error: 0.0939 - val_loss: 0.0274 - val_mean_absolute_error: 0.1193
# Epoch 29/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0145 - mean_absolute_error: 0.0910 - val_loss: 0.0287 - val_mean_absolute_error: 0.1246
# Epoch 30/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0146 - mean_absolute_error: 0.0917 - val_loss: 0.0283 - val_mean_absolute_error: 0.1220
# Epoch 31/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0134 - mean_absolute_error: 0.0878 - val_loss: 0.0276 - val_mean_absolute_error: 0.1221
# Epoch 32/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0134 - mean_absolute_error: 0.0888 - val_loss: 0.0307 - val_mean_absolute_error: 0.1274
# Epoch 33/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0139 - mean_absolute_error: 0.0900 - val_loss: 0.0298 - val_mean_absolute_error: 0.1248
# Epoch 34/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0128 - mean_absolute_error: 0.0868 - val_loss: 0.0330 - val_mean_absolute_error: 0.1357
# Epoch 35/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0119 - mean_absolute_error: 0.0836 - val_loss: 0.0290 - val_mean_absolute_error: 0.1247
# Epoch 36/50
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0111 - mean_absolute_error: 0.0804 - val_loss: 0.0305 - val_mean_absolute_error: 0.1268
# Epoch 37/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0797 - val_loss: 0.0300 - val_mean_absolute_error: 0.1259
# Epoch 38/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0750 - val_loss: 0.0305 - val_mean_absolute_error: 0.1289
# Epoch 39/50
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0104 - mean_absolute_error: 0.0786 - val_loss: 0.0315 - val_mean_absolute_error: 0.1301
# Epoch 40/50
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0099 - mean_absolute_error: 0.0766 - val_loss: 0.0325 - val_mean_absolute_error: 0.1313
# Epoch 41/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0774 - val_loss: 0.0342 - val_mean_absolute_error: 0.1360
# Epoch 42/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0086 - mean_absolute_error: 0.0708 - val_loss: 0.0335 - val_mean_absolute_error: 0.1349
# Epoch 43/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0081 - mean_absolute_error: 0.0694 - val_loss: 0.0331 - val_mean_absolute_error: 0.1339
# Epoch 44/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0086 - mean_absolute_error: 0.0724 - val_loss: 0.0329 - val_mean_absolute_error: 0.1318
# Epoch 45/50
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0082 - mean_absolute_error: 0.0701 - val_loss: 0.0343 - val_mean_absolute_error: 0.1365
# Epoch 46/50
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0071 - mean_absolute_error: 0.0657 - val_loss: 0.0343 - val_mean_absolute_error: 0.1391
# Epoch 47/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0068 - mean_absolute_error: 0.0639 - val_loss: 0.0332 - val_mean_absolute_error: 0.1349
# Epoch 48/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0069 - mean_absolute_error: 0.0645 - val_loss: 0.0327 - val_mean_absolute_error: 0.1341
# Epoch 49/50
# 86/86 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_absolute_error: 0.0611 - val_loss: 0.0340 - val_mean_absolute_error: 0.1357
# Epoch 50/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0058 - mean_absolute_error: 0.0591 - val_loss: 0.0368 - val_mean_absolute_error: 0.1433

# %%
### Get prediction on the test data and convert the result back to stock price (i.e., de-normalization)
from sklearn.metrics import mean_squared_error

# Get prediction on the test data
y_pred_norm = model.predict(X_test_norm)
print("MSE on the test set: ", mean_squared_error(y_pred_norm, y_test_norm))
# Out:
# 27/27 [==============================] - 0s 3ms/step
# MSE on the test set:  0.05004467073234513

# %%
train_predictions = model.predict(X_train_norm).flatten()

plt.plot(train_dates, train_predictions)
plt.plot(train_dates, y_train_norm)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 86/86 [==============================] - 0s 2ms/step

# %%
train_predictions = model.predict(X_val_norm).flatten()

plt.plot(val_dates, train_predictions)
plt.plot(val_dates, y_val_norm)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 22/22 [==============================] - 0s 2ms/step

# %%
test_predictions = model.predict(X_test_norm).flatten()

plt.plot(test_dates, test_predictions)
plt.plot(test_dates, y_test_norm)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 27/27 [==============================] - 0s 2ms/step

# %%
# Convert the result back to stock price (i.e., de-normalization) for visualization purpose
y_pred_denorm = y_pred_norm
for i in range(0, len(y_pred_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(X_test_1[i])
    max_feature = np.max(X_test_1[i])
    y_pred_denorm[i] = y_pred_norm[i] * (max_feature - min_feature) + min_feature

# %%
plt.plot(test_dates, y_pred_denorm)
plt.plot(test_dates, y_test_1)

plt.xlabel('Year', fontsize = 20)
plt.ylabel('Close price in $', fontsize = 20)
plt.legend(['Prediction', 'Real Price'], fontsize = 20)
plt.grid() # Add grid
plt.show()

# %%
# from copy import deepcopy

# recursive_predictions = []
# recursive_dates = np.concatenate([val_dates, test_dates])

# for target_date in recursive_dates:
#     last_window = deepcopy(X_train_norm[-1])
#     next_prediction = model.predict(np.array([last_window])).flatten()
#     recursive_predictions.append(next_prediction)
#     last_window[-1] = next_prediction

# %%
# df = data_appl
X_data = []
y_data = []
dates = []
window_size = 30 # Time window for data feature (size of 'number of days') to learn.
forecast_days = 7 # Number of days to forecast

# Only get the open price (index 2 in the data frame)
for i in range(1, len(df) - window_size - forecast_days):
    first = df.iloc[i, 0]
    data_feature = []
    data_label = []
    
    # Get a window_size time frame for data feature
    for j in range(window_size):
        data_feature.append(df.iloc[i + j, 0])
        
    # Next 7 values are the label (prices of the next 7 days) to be predicted
    for k in range(forecast_days):
        data_label.append(df.iloc[i + window_size + k, 0])
    
    # Append new data sample (feature and label) to X_data and y_data
    X_data.append(np.array(data_feature).reshape(window_size, 1))
    y_data.append(np.array(data_label))
    dates.append(df.iloc[i + window_size, :].name)

X_train, y_train, X_val, y_val, X_test, y_test, train_dates, val_dates, test_dates = pp.split_dataset(X_data, y_data, dates)

# Normalize data
X_train_norm, y_train_norm = pp.normalize_data(X_train, y_train)
X_val_norm, y_val_norm = pp.normalize_data(X_val, y_val)
X_test_norm, y_test_norm = pp.normalize_data(X_test, y_test)


# Build the model architecture
model2 = Sequential()
model2.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(window_size, 1), padding='same'))
model2.add(MaxPooling1D(pool_size=2))
model2.add(Conv1D(128, kernel_size=3, activation='relu', padding='same'))
model2.add(MaxPooling1D(2))
model2.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
model2.add(MaxPooling1D(2))
model2.add(Flatten())
model2.add(Dense(100, activation='relu'))
model2.add(Dense(1)) # By default: activation='linear', i.e., passing through f(x) = x

# Compile and train the model with Mean Squared Error loss function
model2.compile(optimizer= Adam(learning_rate=0.001), 
              loss='mse', 
              metrics=['mean_absolute_error'])
model_training2 = model2.fit(X_train_norm, y_train_norm, validation_data=(X_val_norm,y_val_norm), epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 2s 25ms/step - loss: 0.2957 - mean_absolute_error: 0.4359 - val_loss: 0.2071 - val_mean_absolute_error: 0.3445
# Epoch 2/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.1671 - mean_absolute_error: 0.3135 - val_loss: 0.1447 - val_mean_absolute_error: 0.2710
# Epoch 3/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.1365 - mean_absolute_error: 0.2744 - val_loss: 0.1293 - val_mean_absolute_error: 0.2546
# Epoch 4/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.1197 - mean_absolute_error: 0.2510 - val_loss: 0.1128 - val_mean_absolute_error: 0.2366
# Epoch 5/50
# 22/22 [==============================] - 0s 19ms/step - loss: 0.1113 - mean_absolute_error: 0.2390 - val_loss: 0.1093 - val_mean_absolute_error: 0.2339
# Epoch 6/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.1071 - mean_absolute_error: 0.2332 - val_loss: 0.1054 - val_mean_absolute_error: 0.2289
# Epoch 7/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.1067 - mean_absolute_error: 0.2328 - val_loss: 0.1075 - val_mean_absolute_error: 0.2323
# Epoch 8/50
# 22/22 [==============================] - 0s 20ms/step - loss: 0.1038 - mean_absolute_error: 0.2295 - val_loss: 0.1045 - val_mean_absolute_error: 0.2280
# Epoch 9/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.1034 - mean_absolute_error: 0.2291 - val_loss: 0.1041 - val_mean_absolute_error: 0.2278
# Epoch 10/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.1020 - mean_absolute_error: 0.2273 - val_loss: 0.1049 - val_mean_absolute_error: 0.2291
# Epoch 11/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.1024 - mean_absolute_error: 0.2291 - val_loss: 0.1052 - val_mean_absolute_error: 0.2319
# Epoch 12/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.1026 - mean_absolute_error: 0.2299 - val_loss: 0.1031 - val_mean_absolute_error: 0.2290
# Epoch 13/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0992 - mean_absolute_error: 0.2250 - val_loss: 0.1085 - val_mean_absolute_error: 0.2367
# Epoch 14/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0984 - mean_absolute_error: 0.2236 - val_loss: 0.1027 - val_mean_absolute_error: 0.2267
# Epoch 15/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0967 - mean_absolute_error: 0.2224 - val_loss: 0.1000 - val_mean_absolute_error: 0.2268
# Epoch 16/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0961 - mean_absolute_error: 0.2219 - val_loss: 0.1013 - val_mean_absolute_error: 0.2273
# Epoch 17/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0946 - mean_absolute_error: 0.2212 - val_loss: 0.1050 - val_mean_absolute_error: 0.2330
# Epoch 18/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0943 - mean_absolute_error: 0.2213 - val_loss: 0.1035 - val_mean_absolute_error: 0.2305
# Epoch 19/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0949 - mean_absolute_error: 0.2233 - val_loss: 0.1023 - val_mean_absolute_error: 0.2287
# Epoch 20/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0919 - mean_absolute_error: 0.2179 - val_loss: 0.1009 - val_mean_absolute_error: 0.2270
# Epoch 21/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0913 - mean_absolute_error: 0.2191 - val_loss: 0.0993 - val_mean_absolute_error: 0.2259
# Epoch 22/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0889 - mean_absolute_error: 0.2168 - val_loss: 0.1094 - val_mean_absolute_error: 0.2419
# Epoch 23/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0893 - mean_absolute_error: 0.2173 - val_loss: 0.1096 - val_mean_absolute_error: 0.2404
# Epoch 24/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0863 - mean_absolute_error: 0.2133 - val_loss: 0.1028 - val_mean_absolute_error: 0.2314
# Epoch 25/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0846 - mean_absolute_error: 0.2122 - val_loss: 0.1116 - val_mean_absolute_error: 0.2408
# Epoch 26/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0827 - mean_absolute_error: 0.2104 - val_loss: 0.1024 - val_mean_absolute_error: 0.2307
# Epoch 27/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0811 - mean_absolute_error: 0.2085 - val_loss: 0.1053 - val_mean_absolute_error: 0.2373
# Epoch 28/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0882 - mean_absolute_error: 0.2208 - val_loss: 0.1104 - val_mean_absolute_error: 0.2393
# Epoch 29/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0793 - mean_absolute_error: 0.2064 - val_loss: 0.1106 - val_mean_absolute_error: 0.2400
# Epoch 30/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0775 - mean_absolute_error: 0.2061 - val_loss: 0.1062 - val_mean_absolute_error: 0.2358
# Epoch 31/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0767 - mean_absolute_error: 0.2046 - val_loss: 0.1174 - val_mean_absolute_error: 0.2476
# Epoch 32/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0740 - mean_absolute_error: 0.2013 - val_loss: 0.1082 - val_mean_absolute_error: 0.2375
# Epoch 33/50
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0729 - mean_absolute_error: 0.2007 - val_loss: 0.1129 - val_mean_absolute_error: 0.2435
# Epoch 34/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0693 - mean_absolute_error: 0.1954 - val_loss: 0.1133 - val_mean_absolute_error: 0.2431
# Epoch 35/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0694 - mean_absolute_error: 0.1957 - val_loss: 0.1162 - val_mean_absolute_error: 0.2440
# Epoch 36/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0694 - mean_absolute_error: 0.1970 - val_loss: 0.1158 - val_mean_absolute_error: 0.2460
# Epoch 37/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0651 - mean_absolute_error: 0.1903 - val_loss: 0.1286 - val_mean_absolute_error: 0.2613
# Epoch 38/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0646 - mean_absolute_error: 0.1906 - val_loss: 0.1290 - val_mean_absolute_error: 0.2603
# Epoch 39/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0652 - mean_absolute_error: 0.1910 - val_loss: 0.1224 - val_mean_absolute_error: 0.2529
# Epoch 40/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0628 - mean_absolute_error: 0.1876 - val_loss: 0.1258 - val_mean_absolute_error: 0.2560
# Epoch 41/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0598 - mean_absolute_error: 0.1841 - val_loss: 0.1214 - val_mean_absolute_error: 0.2534
# Epoch 42/50
# 22/22 [==============================] - 0s 18ms/step - loss: 0.0614 - mean_absolute_error: 0.1872 - val_loss: 0.1188 - val_mean_absolute_error: 0.2499
# Epoch 43/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0600 - mean_absolute_error: 0.1853 - val_loss: 0.1272 - val_mean_absolute_error: 0.2585
# Epoch 44/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0581 - mean_absolute_error: 0.1817 - val_loss: 0.1317 - val_mean_absolute_error: 0.2639
# Epoch 45/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0566 - mean_absolute_error: 0.1795 - val_loss: 0.1292 - val_mean_absolute_error: 0.2594
# Epoch 46/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0566 - mean_absolute_error: 0.1794 - val_loss: 0.1230 - val_mean_absolute_error: 0.2527
# Epoch 47/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0546 - mean_absolute_error: 0.1766 - val_loss: 0.1295 - val_mean_absolute_error: 0.2591
# Epoch 48/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0533 - mean_absolute_error: 0.1746 - val_loss: 0.1272 - val_mean_absolute_error: 0.2574
# Epoch 49/50
# 22/22 [==============================] - 0s 17ms/step - loss: 0.0532 - mean_absolute_error: 0.1744 - val_loss: 0.1283 - val_mean_absolute_error: 0.2579
# Epoch 50/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0508 - mean_absolute_error: 0.1708 - val_loss: 0.1276 - val_mean_absolute_error: 0.2568

# %%
### Get prediction on the test data and convert the result back to stock price (i.e., de-normalization)
from sklearn.metrics import mean_squared_error
y_test_norm = y_test_norm.reshape(len(y_test_norm), 7)
# Get prediction on the test data
y_pred_norm = model2.predict(X_test_norm)
# print("MSE on the test set: ", mean_squared_error(y_test_norm, y_pred_norm))
# Out:
# 27/27 [==============================] - 0s 4ms/step

# %%
y_pred_norm = model2.predict(X_test_norm)
y_pred_norm[1]
# Out:
# 27/27 [==============================] - 0s 3ms/step
# array([0.9007332], dtype=float32)

# %%
# Rescale the predicted prices to the original range
y_pred_norm = model.predict(X_test_norm)
y_pred_denorm = y_pred_norm
for i in range(0, len(y_pred_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(X_test[i])
    max_feature = np.max(X_test[i])
    y_pred_denorm[i] = y_pred_norm[i] * (max_feature - min_feature) + min_feature
# Out:
# 27/27 [==============================] - 0s 3ms/step

# %%
y_pred_denorm[-2]
# Out:
# array([13.540812], dtype=float32)

# %%
y_test[-1]
# Out:
# array([13.97999954, 13.97000027, 14.10999966, 14.32999992, 13.55000019,
#        13.60000038, 13.52999973])

# %%
# Get the latest 30-day data to predict for the prices of the next 7 days in the future
latest_30_days = df.iloc[-30:, 0].values.reshape(1, window_size, 1)

# Normalize the latest 30-day data
latest_30_days_norm = latest_30_days.copy()
for i in range(0, len(latest_30_days_norm)):
    min_feature = np.min(latest_30_days[i])
    max_feature = np.max(latest_30_days[i])
    latest_30_days_norm[i] = (latest_30_days[i] - min_feature) / (max_feature - min_feature)
predicted_prices_norm = model.predict(latest_30_days_norm)

# Use the trained model to predict the prices for the next 7 days
predicted_prices_denorm = predicted_prices_norm
for i in range(0, len(predicted_prices_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(latest_30_days[i])
    max_feature = np.max(latest_30_days[i])
    predicted_prices_denorm[i] = predicted_prices_norm[i] * (max_feature - min_feature) + min_feature

# Print the predicted prices for the next 7 days
print(predicted_prices_denorm)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [[14.4786]]

# %%
predicted_prices_denorm = predicted_prices_denorm.flatten()
# Select the latest 2 years from the test_dates
test_dates_latest_2years = [d for d in test_dates if d >= test_dates[-1] - datetime.timedelta(days=365*2)]

# Create a list of the next 7 dates
next_7_dates = [test_dates_latest_2years[-1] + datetime.timedelta(days=x) for x in range(1, 8)]

# Plot the predicted prices in the next 7 days
plt.plot(next_7_dates, predicted_prices_denorm, label = 'Predicted Price for a week in the future')
plt.plot(test_dates_latest_2years, y_test_1[-len(test_dates_latest_2years):], label = 'Current Real Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tt/ldm2rsns0fb1tkl1411f3_g00000gn/T/ipykernel_25948/3655735565.py in <module>
#       7
#       8 # Plot the predicted prices in the next 7 days
# ----> 9 plt.plot(next_7_dates, predicted_prices_denorm, label = 'Predicted Price for a week in the future')
#      10 plt.plot(test_dates_latest_2years, y_test_1[-len(test_dates_latest_2years):], label = 'Current Real Price')
#      11 plt.xlabel('Date')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (7,) and (1,)
