# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df_AAL = pd.read_csv('data_nasdaq/data_nasdaq_csv/AAL.csv')
df_AAL
# Out:
#             Date        Low       Open    Volume       High      Close  \
# 0     27-09-2005  19.100000  21.049999    961200  21.400000  19.299999
# 1     28-09-2005  19.200001  19.299999   5747900  20.530001  20.500000
# 2     29-09-2005  20.100000  20.400000   1078200  20.580000  20.209999
# 3     30-09-2005  20.180000  20.260000   3123300  21.049999  21.010000
# 4     03-10-2005  20.900000  20.900000   1057900  21.750000  21.500000
# ...          ...        ...        ...       ...        ...        ...
# 4328  06-12-2022  14.000000  14.140000  20781500  14.340000  14.330000
# 4329  07-12-2022  13.530000  14.240000  28161400  14.240000  13.550000
# 4330  08-12-2022  13.380000  13.650000  25300900  13.800000  13.600000
# 4331  09-12-2022  13.420000  13.520000  18489800  13.660000  13.530000
# 4332  12-12-2022  13.450000  13.490000   8048550  13.930000  13.915000
#
#       Adjusted Close
# 0          18.194910
# 1          19.326204
# 2          19.052805
# 3          19.807001
# 4          20.268940
# ...              ...
# 4328       14.330000
# 4329       13.550000
# 4330       13.600000
# 4331       13.530000
# 4332       13.915000
#
# [4333 rows x 7 columns]

# %%
df = df_AAL.drop(columns = ['Low', 'High', 'Open', 'Adjusted Close', 'Volume'], axis = 1)

# %%
import datetime
def str_to_datetime(s):
    try:
        split = s.split('-')
        day, month, year = int(split[0]), int(split[1]), int(split[2])
        return datetime.datetime(day=day, month=month, year=year)
    except ValueError:
        print(f"Invalid date string: {s}")
        return None
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# 0      2005-09-27
# 1      2005-09-28
# 2      2005-09-29
# 3      2005-09-30
# 4      2005-10-03
#           ...
# 4328   2022-12-06
# 4329   2022-12-07
# 4330   2022-12-08
# 4331   2022-12-09
# 4332   2022-12-12
# Name: Date, Length: 4333, dtype: datetime64[ns]

# %%
# Set date as the index
df.index = df.pop('Date')

# %%
plt.rcParams['figure.figsize'] = (18, 12)

def price(x):
    """
    format the coords message box
    :param x: data to be formatted
    :return: formatted data
    """
    return '$%1.2f' % x

fig, ax = plt.subplots()
ax.plot(df.index, df['Close'], '#0A7388')
ax.format_ydata = price
# Add labels
plt.ylabel("Price USD")
plt.xlabel("Date")

plt.show()

# %%
### Split the dataset into time windows to get data samples.

# df = data_appl
X_data = []
y_data = []
dates = []
window_size = 30 # Time window for data feature (size of 'number of days') to learn.

# Only get the open price (index 2 in the data frame)
for i in range(1, len(df) - window_size - 1):
    first = df.iloc[i, 0]
    data_feature = []
    data_label = []
    
    # Get a window_size time frame for data feature
    for j in range(window_size):
        data_feature.append(df.iloc[i + j, 0])
        
    # Next value is the label (price of the next day) to be predicted
    data_label.append(df.iloc[i + window_size, 0])
    
    # Append new data sample (feature and label) to X_data and y_data
    X_data.append(np.array(data_feature).reshape(window_size, 1))
    y_data.append(np.array(data_label))
    dates.append(df.iloc[i + window_size, :].name)

# %%
len(X_data), len(y_data), len(dates)
# Out:
# (4301, 4301, 4301)

# %%
from data_nasdaq import data_preprocessing as pp
X_train_1, y_train_1, X_val_1, y_val_1, X_test_1, y_test_1, train_dates, val_dates, test_dates = pp.split_dataset(X_data, y_data, dates)

# %%
# Visualize the training, validation and test set
fig, ax = plt.subplots(figsize = (16,8))
df_plot = df['Close']
df_plot = df_plot.reset_index(drop=False)
plt.plot(train_dates, y_train_1)
plt.plot(val_dates, y_val_1)
plt.plot(test_dates, y_test_1)
plt.xlabel('Year')
plt.ylabel('Close price in $')
plt.legend(['Train', 'Validation', 'Test'])

# Add vertical lines to separate training, validation, and test sets
plt.axvline(x=train_dates[-1], color='k', linestyle='--')
plt.axvline(x=val_dates[-1], color='k', linestyle='--')

plt.show()

# %%
# Normalize data
X_train_norm, y_train_norm = pp.normalize_data(X_train_1, y_train_1)
X_val_norm, y_val_norm = pp.normalize_data(X_val_1, y_val_1)
X_test_norm, y_test_norm = pp.normalize_data(X_test_1, y_test_1)

# %%
### Create and train the model

# Import libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, LSTM, Dropout, Activation

# Build the model architecture
model = Sequential()
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(window_size, 1), padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1)) # By default: activation='linear', i.e., passing through f(x) = x

# Compile and train the model with Mean Squared Error loss function
model.compile(optimizer= Adam(learning_rate=0.001), 
              loss='mse', 
              metrics=['mean_absolute_error'])
model_training = model.fit(X_train_norm, y_train_norm, validation_data=(X_val_norm,y_val_norm), epochs=50, batch_size=32)
# Out:
# 2023-05-12 22:12:59.857219: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 86/86 [==============================] - 2s 9ms/step - loss: 0.0907 - mean_absolute_error: 0.2257 - val_loss: 0.0330 - val_mean_absolute_error: 0.1344
# Epoch 2/50
# 86/86 [==============================] - 1s 6ms/step - loss: 0.0290 - mean_absolute_error: 0.1239 - val_loss: 0.0239 - val_mean_absolute_error: 0.1117
# Epoch 3/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0260 - mean_absolute_error: 0.1176 - val_loss: 0.0239 - val_mean_absolute_error: 0.1133
# Epoch 4/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0254 - mean_absolute_error: 0.1160 - val_loss: 0.0240 - val_mean_absolute_error: 0.1130
# Epoch 5/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0251 - mean_absolute_error: 0.1148 - val_loss: 0.0232 - val_mean_absolute_error: 0.1114
# Epoch 6/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0238 - mean_absolute_error: 0.1122 - val_loss: 0.0252 - val_mean_absolute_error: 0.1181
# Epoch 7/50
# 86/86 [==============================] - 1s 7ms/step - loss: 0.0241 - mean_absolute_error: 0.1129 - val_loss: 0.0263 - val_mean_absolute_error: 0.1195
# Epoch 8/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0226 - mean_absolute_error: 0.1096 - val_loss: 0.0267 - val_mean_absolute_error: 0.1209
# Epoch 9/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0227 - mean_absolute_error: 0.1103 - val_loss: 0.0238 - val_mean_absolute_error: 0.1116
# Epoch 10/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0232 - mean_absolute_error: 0.1118 - val_loss: 0.0231 - val_mean_absolute_error: 0.1108
# Epoch 11/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0222 - mean_absolute_error: 0.1089 - val_loss: 0.0231 - val_mean_absolute_error: 0.1100
# Epoch 12/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0213 - mean_absolute_error: 0.1072 - val_loss: 0.0245 - val_mean_absolute_error: 0.1164
# Epoch 13/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0213 - mean_absolute_error: 0.1069 - val_loss: 0.0230 - val_mean_absolute_error: 0.1120
# Epoch 14/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0212 - mean_absolute_error: 0.1076 - val_loss: 0.0238 - val_mean_absolute_error: 0.1117
# Epoch 15/50
# 86/86 [==============================] - 1s 8ms/step - loss: 0.0210 - mean_absolute_error: 0.1076 - val_loss: 0.0264 - val_mean_absolute_error: 0.1206
# Epoch 16/50
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0205 - mean_absolute_error: 0.1057 - val_loss: 0.0249 - val_mean_absolute_error: 0.1152
# Epoch 17/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0204 - mean_absolute_error: 0.1058 - val_loss: 0.0246 - val_mean_absolute_error: 0.1134
# Epoch 18/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0196 - mean_absolute_error: 0.1044 - val_loss: 0.0246 - val_mean_absolute_error: 0.1132
# Epoch 19/50
# 86/86 [==============================] - 2s 21ms/step - loss: 0.0190 - mean_absolute_error: 0.1021 - val_loss: 0.0262 - val_mean_absolute_error: 0.1185
# Epoch 20/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0183 - mean_absolute_error: 0.1007 - val_loss: 0.0260 - val_mean_absolute_error: 0.1156
# Epoch 21/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0177 - mean_absolute_error: 0.0990 - val_loss: 0.0280 - val_mean_absolute_error: 0.1230
# Epoch 22/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0179 - mean_absolute_error: 0.1004 - val_loss: 0.0278 - val_mean_absolute_error: 0.1226
# Epoch 23/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0170 - mean_absolute_error: 0.0976 - val_loss: 0.0269 - val_mean_absolute_error: 0.1201
# Epoch 24/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0160 - mean_absolute_error: 0.0955 - val_loss: 0.0296 - val_mean_absolute_error: 0.1255
# Epoch 25/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0161 - mean_absolute_error: 0.0958 - val_loss: 0.0278 - val_mean_absolute_error: 0.1208
# Epoch 26/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0157 - mean_absolute_error: 0.0951 - val_loss: 0.0297 - val_mean_absolute_error: 0.1268
# Epoch 27/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0146 - mean_absolute_error: 0.0916 - val_loss: 0.0287 - val_mean_absolute_error: 0.1236
# Epoch 28/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0146 - mean_absolute_error: 0.0920 - val_loss: 0.0322 - val_mean_absolute_error: 0.1326
# Epoch 29/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0145 - mean_absolute_error: 0.0917 - val_loss: 0.0299 - val_mean_absolute_error: 0.1238
# Epoch 30/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0134 - mean_absolute_error: 0.0879 - val_loss: 0.0321 - val_mean_absolute_error: 0.1300
# Epoch 31/50
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0128 - mean_absolute_error: 0.0860 - val_loss: 0.0315 - val_mean_absolute_error: 0.1309
# Epoch 32/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0125 - mean_absolute_error: 0.0853 - val_loss: 0.0324 - val_mean_absolute_error: 0.1287
# Epoch 33/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0118 - mean_absolute_error: 0.0832 - val_loss: 0.0326 - val_mean_absolute_error: 0.1316
# Epoch 34/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0115 - mean_absolute_error: 0.0825 - val_loss: 0.0331 - val_mean_absolute_error: 0.1337
# Epoch 35/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0114 - mean_absolute_error: 0.0819 - val_loss: 0.0344 - val_mean_absolute_error: 0.1351
# Epoch 36/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0103 - mean_absolute_error: 0.0777 - val_loss: 0.0343 - val_mean_absolute_error: 0.1355
# Epoch 37/50
# 86/86 [==============================] - 2s 18ms/step - loss: 0.0104 - mean_absolute_error: 0.0784 - val_loss: 0.0333 - val_mean_absolute_error: 0.1320
# Epoch 38/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0097 - mean_absolute_error: 0.0755 - val_loss: 0.0340 - val_mean_absolute_error: 0.1323
# Epoch 39/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0092 - mean_absolute_error: 0.0739 - val_loss: 0.0352 - val_mean_absolute_error: 0.1357
# Epoch 40/50
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0087 - mean_absolute_error: 0.0715 - val_loss: 0.0344 - val_mean_absolute_error: 0.1333
# Epoch 41/50
# 86/86 [==============================] - 2s 19ms/step - loss: 0.0081 - mean_absolute_error: 0.0695 - val_loss: 0.0354 - val_mean_absolute_error: 0.1356
# Epoch 42/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0077 - mean_absolute_error: 0.0676 - val_loss: 0.0341 - val_mean_absolute_error: 0.1340
# Epoch 43/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0083 - mean_absolute_error: 0.0703 - val_loss: 0.0390 - val_mean_absolute_error: 0.1444
# Epoch 44/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0081 - mean_absolute_error: 0.0699 - val_loss: 0.0372 - val_mean_absolute_error: 0.1388
# Epoch 45/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0068 - mean_absolute_error: 0.0639 - val_loss: 0.0390 - val_mean_absolute_error: 0.1425
# Epoch 46/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0068 - mean_absolute_error: 0.0637 - val_loss: 0.0367 - val_mean_absolute_error: 0.1386
# Epoch 47/50
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0060 - mean_absolute_error: 0.0596 - val_loss: 0.0355 - val_mean_absolute_error: 0.1359
# Epoch 48/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0060 - mean_absolute_error: 0.0590 - val_loss: 0.0378 - val_mean_absolute_error: 0.1393
# Epoch 49/50
# 86/86 [==============================] - 2s 21ms/step - loss: 0.0058 - mean_absolute_error: 0.0586 - val_loss: 0.0409 - val_mean_absolute_error: 0.1465
# Epoch 50/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0057 - mean_absolute_error: 0.0580 - val_loss: 0.0376 - val_mean_absolute_error: 0.1389

# %%
### Get prediction on the test data and convert the result back to stock price (i.e., de-normalization)
from sklearn.metrics import mean_squared_error

# Get prediction on the test data
y_pred_norm = model.predict(X_test_norm)
print("MSE on the test set: ", mean_squared_error(y_pred_norm, y_test_norm))
# Out:
# 27/27 [==============================] - 1s 5ms/step
# MSE on the test set:  0.042809046786832575

# %%
y_pred_norm[1]
# Out:
# array([1.1303077], dtype=float32)

# %%
train_predictions = model.predict(X_train_norm).flatten()

plt.plot(train_dates, train_predictions)
plt.plot(train_dates, y_train_norm)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 86/86 [==============================] - 1s 7ms/step

# %%
val_predictions = model.predict(X_val_norm).flatten()

plt.plot(val_dates, val_predictions)
plt.plot(val_dates, y_val_norm)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 22/22 [==============================] - 0s 4ms/step

# %%
test_predictions = model.predict(X_test_norm).flatten()

plt.plot(test_dates, test_predictions)
plt.plot(test_dates, y_test_norm)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 27/27 [==============================] - 0s 4ms/step

# %%
# Convert the result back to stock price (i.e., de-normalization) for visualization purpose
y_pred_denorm = y_pred_norm
for i in range(0, len(y_pred_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(X_test_1[i])
    max_feature = np.max(X_test_1[i])
    y_pred_denorm[i] = y_pred_norm[i] * (max_feature - min_feature) + min_feature

# %%
plt.plot(test_dates, y_pred_denorm)
plt.plot(test_dates, y_test_1)

plt.xlabel('Year', fontsize = 20)
plt.ylabel('Close price in $', fontsize = 20)
plt.legend(['Prediction', 'Real Price'], fontsize = 20)
plt.grid() # Add grid
plt.show()

# %%
# from copy import deepcopy

# recursive_predictions = []
# recursive_dates = np.concatenate([val_dates, test_dates])

# for target_date in recursive_dates:
#     last_window = deepcopy(X_train_norm[-1])
#     next_prediction = model.predict(np.array([last_window])).flatten()
#     recursive_predictions.append(next_prediction)
#     last_window[-1] = next_prediction

# %%
X_data_1 = []
y_data_1 = []
dates = []
window_size = 30 # Time window for data feature (size of 'number of days') to learn.
forecast_days = 7 # Number of days to forecast

# Only get the open price (index 2 in the data frame)
for i in range(1, len(df) - window_size - forecast_days):
    first = df.iloc[i, 0]
    data_features = []
    data_labels = []
    
    # Get a window_size time frame for data feature
    for j in range(window_size):
        data_features.append(df.iloc[i + j, 0])
        
    # Next 7 values are the label (prices of the next 7 days) to be predicted
    for k in range(forecast_days):
        data_labels.append(df.iloc[i + window_size + k, 0])
    
    # Append new data sample (feature and label) to X_data and y_data
    X_data_1.append(np.array(data_features).reshape(window_size, 1))
    y_data_1.append(np.array(data_labels))
    dates.append(df.iloc[i + window_size, :].name)

X_train_1, y_train_1, X_val_1, y_val_1, X_test_1, y_test_1, train_dates, val_dates, test_dates = pp.split_dataset(X_data_1, y_data_1, dates)

# Normalize data
X_train_norm_1, y_train_norm_1 = pp.normalize_data(X_train_1, y_train_1)
X_val_norm_1, y_val_norm_1 = pp.normalize_data(X_val_1, y_val_1)
X_test_norm_1, y_test_norm_1 = pp.normalize_data(X_test_1, y_test_1)

# %%
# Build the model architecture
model2 = Sequential()
model2.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(window_size, 1), padding='same'))
model2.add(MaxPooling1D(pool_size=2))
model2.add(Conv1D(128, kernel_size=3, activation='relu', padding='same'))
model2.add(MaxPooling1D(2))
model2.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
model2.add(MaxPooling1D(2))
model2.add(Flatten())
model2.add(Dense(100, activation='relu'))
model2.add(Dense(1)) # By default: activation='linear', i.e., passing through f(x) = x

# Compile and train the model with Mean Squared Error loss function
model2.compile(optimizer= Adam(learning_rate=0.001), 
              loss='mse', 
              metrics=['mean_absolute_error'])
model_training2 = model2.fit(X_train_norm_1, y_train_norm_1, validation_data=(X_val_norm_1,y_val_norm_1), epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 2s 32ms/step - loss: 0.2538 - mean_absolute_error: 0.3985 - val_loss: 0.1803 - val_mean_absolute_error: 0.3131
# Epoch 2/50
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1499 - mean_absolute_error: 0.2903 - val_loss: 0.1416 - val_mean_absolute_error: 0.2769
# Epoch 3/50
# 22/22 [==============================] - 1s 32ms/step - loss: 0.1303 - mean_absolute_error: 0.2655 - val_loss: 0.1192 - val_mean_absolute_error: 0.2457
# Epoch 4/50
# 22/22 [==============================] - 0s 20ms/step - loss: 0.1190 - mean_absolute_error: 0.2489 - val_loss: 0.1168 - val_mean_absolute_error: 0.2436
# Epoch 5/50
# 22/22 [==============================] - 1s 25ms/step - loss: 0.1121 - mean_absolute_error: 0.2407 - val_loss: 0.1061 - val_mean_absolute_error: 0.2295
# Epoch 6/50
# 22/22 [==============================] - 1s 37ms/step - loss: 0.1103 - mean_absolute_error: 0.2384 - val_loss: 0.1065 - val_mean_absolute_error: 0.2300
# Epoch 7/50
# 22/22 [==============================] - 1s 51ms/step - loss: 0.1064 - mean_absolute_error: 0.2325 - val_loss: 0.1048 - val_mean_absolute_error: 0.2279
# Epoch 8/50
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1052 - mean_absolute_error: 0.2312 - val_loss: 0.1047 - val_mean_absolute_error: 0.2282
# Epoch 9/50
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1034 - mean_absolute_error: 0.2289 - val_loss: 0.1020 - val_mean_absolute_error: 0.2248
# Epoch 10/50
# 22/22 [==============================] - 1s 34ms/step - loss: 0.1022 - mean_absolute_error: 0.2275 - val_loss: 0.1046 - val_mean_absolute_error: 0.2320
# Epoch 11/50
# 22/22 [==============================] - 1s 29ms/step - loss: 0.1012 - mean_absolute_error: 0.2268 - val_loss: 0.1049 - val_mean_absolute_error: 0.2304
# Epoch 12/50
# 22/22 [==============================] - 1s 26ms/step - loss: 0.1018 - mean_absolute_error: 0.2293 - val_loss: 0.0987 - val_mean_absolute_error: 0.2254
# Epoch 13/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.1002 - mean_absolute_error: 0.2262 - val_loss: 0.1020 - val_mean_absolute_error: 0.2291
# Epoch 14/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0993 - mean_absolute_error: 0.2261 - val_loss: 0.0992 - val_mean_absolute_error: 0.2237
# Epoch 15/50
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0984 - mean_absolute_error: 0.2255 - val_loss: 0.1123 - val_mean_absolute_error: 0.2431
# Epoch 16/50
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0986 - mean_absolute_error: 0.2260 - val_loss: 0.1011 - val_mean_absolute_error: 0.2295
# Epoch 17/50
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0957 - mean_absolute_error: 0.2221 - val_loss: 0.1014 - val_mean_absolute_error: 0.2272
# Epoch 18/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0948 - mean_absolute_error: 0.2215 - val_loss: 0.1021 - val_mean_absolute_error: 0.2289
# Epoch 19/50
# 22/22 [==============================] - 1s 33ms/step - loss: 0.0933 - mean_absolute_error: 0.2198 - val_loss: 0.1075 - val_mean_absolute_error: 0.2374
# Epoch 20/50
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0924 - mean_absolute_error: 0.2202 - val_loss: 0.1028 - val_mean_absolute_error: 0.2286
# Epoch 21/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0902 - mean_absolute_error: 0.2174 - val_loss: 0.1008 - val_mean_absolute_error: 0.2284
# Epoch 22/50
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0894 - mean_absolute_error: 0.2171 - val_loss: 0.1032 - val_mean_absolute_error: 0.2321
# Epoch 23/50
# 22/22 [==============================] - 0s 23ms/step - loss: 0.0898 - mean_absolute_error: 0.2194 - val_loss: 0.1038 - val_mean_absolute_error: 0.2318
# Epoch 24/50
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0863 - mean_absolute_error: 0.2133 - val_loss: 0.1040 - val_mean_absolute_error: 0.2350
# Epoch 25/50
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0881 - mean_absolute_error: 0.2183 - val_loss: 0.1167 - val_mean_absolute_error: 0.2492
# Epoch 26/50
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0852 - mean_absolute_error: 0.2140 - val_loss: 0.1057 - val_mean_absolute_error: 0.2334
# Epoch 27/50
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0821 - mean_absolute_error: 0.2101 - val_loss: 0.1210 - val_mean_absolute_error: 0.2553
# Epoch 28/50
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0866 - mean_absolute_error: 0.2179 - val_loss: 0.1095 - val_mean_absolute_error: 0.2408
# Epoch 29/50
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0805 - mean_absolute_error: 0.2091 - val_loss: 0.1143 - val_mean_absolute_error: 0.2474
# Epoch 30/50
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0815 - mean_absolute_error: 0.2105 - val_loss: 0.1089 - val_mean_absolute_error: 0.2392
# Epoch 31/50
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0780 - mean_absolute_error: 0.2057 - val_loss: 0.1128 - val_mean_absolute_error: 0.2456
# Epoch 32/50
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0757 - mean_absolute_error: 0.2039 - val_loss: 0.1117 - val_mean_absolute_error: 0.2448
# Epoch 33/50
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0743 - mean_absolute_error: 0.2021 - val_loss: 0.1153 - val_mean_absolute_error: 0.2499
# Epoch 34/50
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0760 - mean_absolute_error: 0.2054 - val_loss: 0.1084 - val_mean_absolute_error: 0.2391
# Epoch 35/50
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0727 - mean_absolute_error: 0.2001 - val_loss: 0.1092 - val_mean_absolute_error: 0.2409
# Epoch 36/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0721 - mean_absolute_error: 0.2000 - val_loss: 0.1134 - val_mean_absolute_error: 0.2471
# Epoch 37/50
# 22/22 [==============================] - 1s 25ms/step - loss: 0.0707 - mean_absolute_error: 0.1981 - val_loss: 0.1154 - val_mean_absolute_error: 0.2492
# Epoch 38/50
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0673 - mean_absolute_error: 0.1934 - val_loss: 0.1157 - val_mean_absolute_error: 0.2528
# Epoch 39/50
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0662 - mean_absolute_error: 0.1922 - val_loss: 0.1146 - val_mean_absolute_error: 0.2490
# Epoch 40/50
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0656 - mean_absolute_error: 0.1916 - val_loss: 0.1200 - val_mean_absolute_error: 0.2557
# Epoch 41/50
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0637 - mean_absolute_error: 0.1888 - val_loss: 0.1203 - val_mean_absolute_error: 0.2573
# Epoch 42/50
# 22/22 [==============================] - 1s 35ms/step - loss: 0.0632 - mean_absolute_error: 0.1889 - val_loss: 0.1186 - val_mean_absolute_error: 0.2526
# Epoch 43/50
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0624 - mean_absolute_error: 0.1877 - val_loss: 0.1174 - val_mean_absolute_error: 0.2521
# Epoch 44/50
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0617 - mean_absolute_error: 0.1864 - val_loss: 0.1241 - val_mean_absolute_error: 0.2581
# Epoch 45/50
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0601 - mean_absolute_error: 0.1843 - val_loss: 0.1204 - val_mean_absolute_error: 0.2554
# Epoch 46/50
# 22/22 [==============================] - 1s 47ms/step - loss: 0.0604 - mean_absolute_error: 0.1853 - val_loss: 0.1192 - val_mean_absolute_error: 0.2548
# Epoch 47/50
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0580 - mean_absolute_error: 0.1807 - val_loss: 0.1276 - val_mean_absolute_error: 0.2662
# Epoch 48/50
# 22/22 [==============================] - 1s 66ms/step - loss: 0.0566 - mean_absolute_error: 0.1789 - val_loss: 0.1290 - val_mean_absolute_error: 0.2672
# Epoch 49/50
# 22/22 [==============================] - 1s 48ms/step - loss: 0.0558 - mean_absolute_error: 0.1779 - val_loss: 0.1265 - val_mean_absolute_error: 0.2625
# Epoch 50/50
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0544 - mean_absolute_error: 0.1760 - val_loss: 0.1322 - val_mean_absolute_error: 0.2670

# %%
### Get prediction on the test data and convert the result back to stock price (i.e., de-normalization)
from sklearn.metrics import mean_squared_error
# Get prediction on the test data
y_pred_norm_1 = model2.predict(X_test_norm_1)
y_pred_norm_1[1]
# print("MSE on the test set: ", mean_squared_error(y_test_norm, y_pred_norm))
# Out:
# 27/27 [==============================] - 0s 4ms/step
# array([1.0963124], dtype=float32)

# %%
y_test_norm_1[1]

# %%
y_pred_norm = model2.predict(X_test_norm)
y_pred_norm[1]

# %%
# Rescale the predicted prices to the original range
y_pred_norm = model.predict(X_test_norm)
y_pred_denorm = y_pred_norm
for i in range(0, len(y_pred_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(X_test[i])
    max_feature = np.max(X_test[i])
    y_pred_denorm[i] = y_pred_norm[i] * (max_feature - min_feature) + min_feature

# %%
y_pred_denorm[-2]

# %%
y_test[-1]

# %%
# Get the latest 30-day data to predict for the prices of the next 7 days in the future
latest_30_days = df.iloc[-30:, 0].values.reshape(1, window_size, 1)

# Normalize the latest 30-day data
latest_30_days_norm = latest_30_days.copy()
for i in range(0, len(latest_30_days_norm)):
    min_feature = np.min(latest_30_days[i])
    max_feature = np.max(latest_30_days[i])
    latest_30_days_norm[i] = (latest_30_days[i] - min_feature) / (max_feature - min_feature)
predicted_prices_norm = model.predict(latest_30_days_norm)

# Use the trained model to predict the prices for the next 7 days
predicted_prices_denorm = predicted_prices_norm
for i in range(0, len(predicted_prices_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(latest_30_days[i])
    max_feature = np.max(latest_30_days[i])
    predicted_prices_denorm[i] = predicted_prices_norm[i] * (max_feature - min_feature) + min_feature

# Print the predicted prices for the next 7 days
print(predicted_prices_denorm)

# %%
predicted_prices_denorm = predicted_prices_denorm.flatten()
# Select the latest 2 years from the test_dates
test_dates_latest_2years = [d for d in test_dates if d >= test_dates[-1] - datetime.timedelta(days=365*2)]

# Create a list of the next 7 dates
next_7_dates = [test_dates_latest_2years[-1] + datetime.timedelta(days=x) for x in range(1, 8)]

# Plot the predicted prices in the next 7 days
plt.plot(next_7_dates, predicted_prices_denorm, label = 'Predicted Price for a week in the future')
plt.plot(test_dates_latest_2years, y_test_1[-len(test_dates_latest_2years):], label = 'Current Real Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
