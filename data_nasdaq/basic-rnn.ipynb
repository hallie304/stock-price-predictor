# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df_AAL = pd.read_csv('../data_nasdaq/data_nasdaq_csv/AAL.csv')
df_AAL
# Out:
#             Date        Low       Open    Volume       High      Close  \
# 0     27-09-2005  19.100000  21.049999    961200  21.400000  19.299999
# 1     28-09-2005  19.200001  19.299999   5747900  20.530001  20.500000
# 2     29-09-2005  20.100000  20.400000   1078200  20.580000  20.209999
# 3     30-09-2005  20.180000  20.260000   3123300  21.049999  21.010000
# 4     03-10-2005  20.900000  20.900000   1057900  21.750000  21.500000
# ...          ...        ...        ...       ...        ...        ...
# 4328  06-12-2022  14.000000  14.140000  20781500  14.340000  14.330000
# 4329  07-12-2022  13.530000  14.240000  28161400  14.240000  13.550000
# 4330  08-12-2022  13.380000  13.650000  25300900  13.800000  13.600000
# 4331  09-12-2022  13.420000  13.520000  18489800  13.660000  13.530000
# 4332  12-12-2022  13.450000  13.490000   8048550  13.930000  13.915000
#
#       Adjusted Close
# 0          18.194910
# 1          19.326204
# 2          19.052805
# 3          19.807001
# 4          20.268940
# ...              ...
# 4328       14.330000
# 4329       13.550000
# 4330       13.600000
# 4331       13.530000
# 4332       13.915000
#
# [4333 rows x 7 columns]

# %%
df = df_AAL.drop(columns = ['Low', 'High', 'Open', 'Adjusted Close', 'Volume'], axis = 1)

# %%
import datetime
def str_to_datetime(s):
    try:
        split = s.split('-')
        day, month, year = int(split[0]), int(split[1]), int(split[2])
        return datetime.datetime(day=day, month=month, year=year)
    except ValueError:
        print(f"Invalid date string: {s}")
        return None
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# 0      2005-09-27
# 1      2005-09-28
# 2      2005-09-29
# 3      2005-09-30
# 4      2005-10-03
#           ...
# 4328   2022-12-06
# 4329   2022-12-07
# 4330   2022-12-08
# 4331   2022-12-09
# 4332   2022-12-12
# Name: Date, Length: 4333, dtype: datetime64[ns]

# %%
# Set date as the index
df.index = df.pop('Date')

# %%
plt.rcParams['figure.figsize'] = (18, 12)

def price(x):
    """
    format the coords message box
    :param x: data to be formatted
    :return: formatted data
    """
    return '$%1.2f' % x

fig, ax = plt.subplots()
ax.plot(df.index, df['Close'], '#0A7388')
ax.format_ydata = price
# Add labels
plt.ylabel("Price USD")
plt.xlabel("Date")

plt.show()

# %%
### Split the dataset into time windows to get data samples.

# df = data_appl
X_data = []
y_data = []
dates = []
window_size = 30 # Time window for data feature (size of 'number of days') to learn.

# Only get the open price (index 2 in the data frame)
for i in range(1, len(df) - window_size - 1):
    first = df.iloc[i, 0]
    data_feature = []
    data_label = []
    
    # Get a window_size time frame for data feature
    for j in range(window_size):
        data_feature.append(df.iloc[i + j, 0])
        
    # Next value is the label (price of the next day) to be predicted
    data_label.append(df.iloc[i + window_size, 0])
    
    # Append new data sample (feature and label) to X_data and y_data
    X_data.append(np.array(data_feature).reshape(window_size, 1))
    y_data.append(np.array(data_label))
    dates.append(df.iloc[i + window_size, :].name)

# %%
len(X_data), len(y_data), len(dates)
# Out:
# (4301, 4301, 4301)

# %%
import data_preprocessing as pp
X_train, y_train, X_val, y_val, X_test, y_test, train_dates, val_dates, test_dates = pp.split_dataset(X_data, y_data, dates)

# %%
# Visualize the training, validation and test set
fig, ax = plt.subplots(figsize = (16,8))
df_plot = df['Close']
df_plot = df_plot.reset_index(drop=False)
plt.plot(train_dates, y_train)
plt.plot(val_dates, y_val)
plt.plot(test_dates, y_test)
plt.xlabel('Year')
plt.ylabel('Close price in $')
plt.legend(['Train', 'Validation', 'Test'])

# Add vertical lines to separate training, validation, and test sets
plt.axvline(x=train_dates[-1], color='k', linestyle='--')
plt.axvline(x=val_dates[-1], color='k', linestyle='--')

plt.show()

# %%
# Normalize data
X_train_norm, y_train_norm = pp.normalize_data(X_train, y_train)
X_val_norm, y_val_norm = pp.normalize_data(X_val, y_val)
X_test_norm, y_test_norm = pp.normalize_data(X_test, y_test)

# %%
### Create and train the model

# Import libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, LSTM, Dropout, Activation

# Build the model architecture
model = Sequential()
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(window_size, 1), padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1)) # By default: activation='linear', i.e., passing through f(x) = x

# Compile and train the model with Mean Squared Error loss function
model.compile(optimizer= Adam(learning_rate=0.001), 
              loss='mse', 
              metrics=['mean_absolute_error'])
model_training = model.fit(X_train_norm, y_train_norm, validation_data=(X_val_norm,y_val_norm), epochs=50, batch_size=32)
# Out:
# 2023-05-19 02:37:51.894969: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 86/86 [==============================] - 3s 16ms/step - loss: 0.0853 - mean_absolute_error: 0.2169 - val_loss: 0.0351 - val_mean_absolute_error: 0.1366
# Epoch 2/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0309 - mean_absolute_error: 0.1282 - val_loss: 0.0276 - val_mean_absolute_error: 0.1246
# Epoch 3/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0267 - mean_absolute_error: 0.1191 - val_loss: 0.0242 - val_mean_absolute_error: 0.1151
# Epoch 4/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0267 - mean_absolute_error: 0.1199 - val_loss: 0.0245 - val_mean_absolute_error: 0.1145
# Epoch 5/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0253 - mean_absolute_error: 0.1155 - val_loss: 0.0233 - val_mean_absolute_error: 0.1109
# Epoch 6/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0242 - mean_absolute_error: 0.1136 - val_loss: 0.0229 - val_mean_absolute_error: 0.1103
# Epoch 7/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0237 - mean_absolute_error: 0.1114 - val_loss: 0.0238 - val_mean_absolute_error: 0.1121
# Epoch 8/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0235 - mean_absolute_error: 0.1112 - val_loss: 0.0232 - val_mean_absolute_error: 0.1105
# Epoch 9/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0237 - mean_absolute_error: 0.1130 - val_loss: 0.0259 - val_mean_absolute_error: 0.1228
# Epoch 10/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0231 - mean_absolute_error: 0.1104 - val_loss: 0.0236 - val_mean_absolute_error: 0.1144
# Epoch 11/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0224 - mean_absolute_error: 0.1094 - val_loss: 0.0242 - val_mean_absolute_error: 0.1147
# Epoch 12/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0225 - mean_absolute_error: 0.1100 - val_loss: 0.0246 - val_mean_absolute_error: 0.1167
# Epoch 13/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0219 - mean_absolute_error: 0.1076 - val_loss: 0.0252 - val_mean_absolute_error: 0.1145
# Epoch 14/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0215 - mean_absolute_error: 0.1069 - val_loss: 0.0244 - val_mean_absolute_error: 0.1151
# Epoch 15/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0214 - mean_absolute_error: 0.1085 - val_loss: 0.0277 - val_mean_absolute_error: 0.1240
# Epoch 16/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0207 - mean_absolute_error: 0.1059 - val_loss: 0.0249 - val_mean_absolute_error: 0.1150
# Epoch 17/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0208 - mean_absolute_error: 0.1058 - val_loss: 0.0247 - val_mean_absolute_error: 0.1153
# Epoch 18/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0201 - mean_absolute_error: 0.1052 - val_loss: 0.0243 - val_mean_absolute_error: 0.1130
# Epoch 19/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0197 - mean_absolute_error: 0.1043 - val_loss: 0.0248 - val_mean_absolute_error: 0.1149
# Epoch 20/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0192 - mean_absolute_error: 0.1034 - val_loss: 0.0264 - val_mean_absolute_error: 0.1196
# Epoch 21/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0186 - mean_absolute_error: 0.1018 - val_loss: 0.0244 - val_mean_absolute_error: 0.1132
# Epoch 22/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0177 - mean_absolute_error: 0.0997 - val_loss: 0.0255 - val_mean_absolute_error: 0.1172
# Epoch 23/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0180 - mean_absolute_error: 0.1009 - val_loss: 0.0241 - val_mean_absolute_error: 0.1132
# Epoch 24/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0168 - mean_absolute_error: 0.0973 - val_loss: 0.0256 - val_mean_absolute_error: 0.1176
# Epoch 25/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0165 - mean_absolute_error: 0.0968 - val_loss: 0.0262 - val_mean_absolute_error: 0.1181
# Epoch 26/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0166 - mean_absolute_error: 0.0969 - val_loss: 0.0276 - val_mean_absolute_error: 0.1238
# Epoch 27/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0161 - mean_absolute_error: 0.0966 - val_loss: 0.0377 - val_mean_absolute_error: 0.1512
# Epoch 28/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0153 - mean_absolute_error: 0.0944 - val_loss: 0.0280 - val_mean_absolute_error: 0.1227
# Epoch 29/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0156 - mean_absolute_error: 0.0950 - val_loss: 0.0271 - val_mean_absolute_error: 0.1204
# Epoch 30/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0137 - mean_absolute_error: 0.0891 - val_loss: 0.0290 - val_mean_absolute_error: 0.1245
# Epoch 31/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0134 - mean_absolute_error: 0.0878 - val_loss: 0.0274 - val_mean_absolute_error: 0.1212
# Epoch 32/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0125 - mean_absolute_error: 0.0853 - val_loss: 0.0284 - val_mean_absolute_error: 0.1223
# Epoch 33/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0124 - mean_absolute_error: 0.0856 - val_loss: 0.0269 - val_mean_absolute_error: 0.1193
# Epoch 34/50
# 86/86 [==============================] - 3s 34ms/step - loss: 0.0129 - mean_absolute_error: 0.0866 - val_loss: 0.0303 - val_mean_absolute_error: 0.1268
# Epoch 35/50
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0109 - mean_absolute_error: 0.0799 - val_loss: 0.0294 - val_mean_absolute_error: 0.1255
# Epoch 36/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0107 - mean_absolute_error: 0.0786 - val_loss: 0.0292 - val_mean_absolute_error: 0.1252
# Epoch 37/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0099 - mean_absolute_error: 0.0765 - val_loss: 0.0306 - val_mean_absolute_error: 0.1289
# Epoch 38/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0099 - mean_absolute_error: 0.0758 - val_loss: 0.0318 - val_mean_absolute_error: 0.1316
# Epoch 39/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0095 - mean_absolute_error: 0.0747 - val_loss: 0.0314 - val_mean_absolute_error: 0.1301
# Epoch 40/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0089 - mean_absolute_error: 0.0721 - val_loss: 0.0303 - val_mean_absolute_error: 0.1293
# Epoch 41/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0087 - mean_absolute_error: 0.0716 - val_loss: 0.0301 - val_mean_absolute_error: 0.1287
# Epoch 42/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0083 - mean_absolute_error: 0.0698 - val_loss: 0.0312 - val_mean_absolute_error: 0.1304
# Epoch 43/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0084 - mean_absolute_error: 0.0702 - val_loss: 0.0312 - val_mean_absolute_error: 0.1296
# Epoch 44/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0074 - mean_absolute_error: 0.0663 - val_loss: 0.0324 - val_mean_absolute_error: 0.1328
# Epoch 45/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0078 - mean_absolute_error: 0.0677 - val_loss: 0.0330 - val_mean_absolute_error: 0.1347
# Epoch 46/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0070 - mean_absolute_error: 0.0638 - val_loss: 0.0330 - val_mean_absolute_error: 0.1352
# Epoch 47/50
# 86/86 [==============================] - 1s 10ms/step - loss: 0.0071 - mean_absolute_error: 0.0649 - val_loss: 0.0340 - val_mean_absolute_error: 0.1355
# Epoch 48/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0069 - mean_absolute_error: 0.0637 - val_loss: 0.0328 - val_mean_absolute_error: 0.1345
# Epoch 49/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0062 - mean_absolute_error: 0.0610 - val_loss: 0.0337 - val_mean_absolute_error: 0.1367
# Epoch 50/50
# 86/86 [==============================] - 1s 11ms/step - loss: 0.0061 - mean_absolute_error: 0.0599 - val_loss: 0.0346 - val_mean_absolute_error: 0.1378

# %%
### Get prediction on the test data and convert the result back to stock price (i.e., de-normalization)
from sklearn.metrics import mean_squared_error

# Get prediction on the test data
y_pred_norm = model.predict(X_test_norm)
print("MSE on the test set: ", mean_squared_error(y_pred_norm, y_test_norm))
# Out:
# 27/27 [==============================] - 0s 4ms/step
# MSE on the test set:  0.043841802960840275

# %%
y_pred_norm[1]
# Out:
# array([0.9611913], dtype=float32)

# %%
train_predictions = model.predict(X_train_norm).flatten()

plt.plot(train_dates, train_predictions)
plt.plot(train_dates, y_train_norm)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 86/86 [==============================] - 0s 3ms/step

# %%
val_predictions = model.predict(X_val_norm).flatten()

plt.plot(val_dates, val_predictions)
plt.plot(val_dates, y_val_norm)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 22/22 [==============================] - 0s 5ms/step

# %%
test_predictions = model.predict(X_test_norm).flatten()

plt.plot(test_dates, test_predictions)
plt.plot(test_dates, y_test_norm)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 27/27 [==============================] - 0s 13ms/step

# %%
# Convert the result back to stock price (i.e., de-normalization) for visualization purpose
y_pred_denorm = y_pred_norm
for i in range(0, len(y_pred_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(X_test[i])
    max_feature = np.max(X_test[i])
    y_pred_denorm[i] = y_pred_norm[i] * (max_feature - min_feature) + min_feature

# %%
plt.plot(test_dates, y_pred_denorm)
plt.plot(test_dates, y_test)

plt.xlabel('Year', fontsize = 20)
plt.ylabel('Close price in $', fontsize = 20)
plt.legend(['Prediction', 'Real Price'], fontsize = 20)
plt.grid() # Add grid
plt.show()

# %%
# from copy import deepcopy

# recursive_predictions = []
# recursive_dates = np.concatenate([val_dates, test_dates])

# for target_date in recursive_dates:
#     last_window = deepcopy(X_train_norm[-1])
#     next_prediction = model.predict(np.array([last_window])).flatten()
#     recursive_predictions.append(next_prediction)
#     last_window[-1] = next_prediction

# %%
X_data_1 = []
y_data_1 = []
dates = []
window_size = 30 # Time window for data feature (size of 'number of days') to learn.
forecast_days = 7 # Number of days to forecast

# Only get the open price (index 2 in the data frame)
for i in range(1, len(df) - window_size - forecast_days):
    first = df.iloc[i, 0]
    data_features = []
    data_labels = []
    
    # Get a window_size time frame for data feature
    for j in range(window_size):
        data_features.append(df.iloc[i + j, 0])
        
    # Next 7 values are the label (prices of the next 7 days) to be predicted
    for k in range(forecast_days):
        data_labels.append(df.iloc[i + window_size + k, 0])
    
    # Append new data sample (feature and label) to X_data and y_data
    X_data_1.append(np.array(data_features).reshape(window_size, 1))
    y_data_1.append(np.array(data_labels))
    dates.append(df.iloc[i + window_size, :].name)

X_train_1, y_train_1, X_val_1, y_val_1, X_test_1, y_test_1, train_dates, val_dates, test_dates = pp.split_dataset(X_data_1, y_data_1, dates)

# Normalize data
X_train_norm_1, y_train_norm_1 = pp.normalize_data(X_train_1, y_train_1)
X_val_norm_1, y_val_norm_1 = pp.normalize_data(X_val_1, y_val_1)
X_test_norm_1, y_test_norm_1 = pp.normalize_data(X_test_1, y_test_1)

# %%
X_train_1[0], y_train_1[0]
# Out:
# (array([[20.5       ],
#         [20.20999908],
#         [21.01000023],
#         [21.5       ],
#         [22.15999985],
#         [22.20000076],
#         [22.57999992],
#         [22.14999962],
#         [22.20999908],
#         [21.97999954],
#         [21.76000023],
#         [21.70999908],
#         [22.27000046],
#         [22.07999992],
#         [21.48999977],
#         [21.37999916],
#         [21.02000046],
#         [21.95999908],
#         [22.30999947],
#         [22.        ],
#         [22.31999969],
#         [22.55999947],
#         [23.89999962],
#         [24.68000031],
#         [25.02000046],
#         [27.54999924],
#         [27.87000084],
#         [28.79999924],
#         [28.93000031],
#         [29.43000031]]),
#  array([31.29999924, 32.79999924, 33.34999847, 33.75      , 33.88000107,
#         33.59999847, 34.31999969]))

# %%
X_train_norm_1.shape, y_train_norm_1.shape
# Out:
# ((2748, 30, 1), (2748, 7))

# %%
X_test_norm_1.shape, y_test_norm_1.shape
# Out:
# ((859, 30, 1), (859, 7))

# %%
# Build the model architecture
model1 = Sequential()
model1.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(window_size, 1), padding='same'))
model1.add(MaxPooling1D(pool_size=2))
model1.add(Conv1D(128, kernel_size=3, activation='relu', padding='same'))
model1.add(MaxPooling1D(2))
model1.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
model1.add(MaxPooling1D(2))
model1.add(Flatten())
model1.add(Dense(100, activation='relu'))
model1.add(Dense(7)) # By default: activation='linear', i.e., passing through f(x) = x

# Compile and train the model with Mean Squared Error loss function
model1.compile(optimizer= Adam(learning_rate=0.001), 
              loss='mse', 
              metrics=['mean_absolute_error'])
model_training1 = model1.fit(X_train_norm_1, y_train_norm_1, validation_data=(X_val_norm_1,y_val_norm_1), epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 2s 33ms/step - loss: 0.3339 - mean_absolute_error: 0.4639 - val_loss: 0.2317 - val_mean_absolute_error: 0.3827
# Epoch 2/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.1972 - mean_absolute_error: 0.3483 - val_loss: 0.1741 - val_mean_absolute_error: 0.2997
# Epoch 3/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.1412 - mean_absolute_error: 0.2794 - val_loss: 0.1301 - val_mean_absolute_error: 0.2528
# Epoch 4/50
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1198 - mean_absolute_error: 0.2505 - val_loss: 0.1185 - val_mean_absolute_error: 0.2416
# Epoch 5/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.1113 - mean_absolute_error: 0.2382 - val_loss: 0.1105 - val_mean_absolute_error: 0.2341
# Epoch 6/50
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1097 - mean_absolute_error: 0.2362 - val_loss: 0.1109 - val_mean_absolute_error: 0.2363
# Epoch 7/50
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1099 - mean_absolute_error: 0.2371 - val_loss: 0.1070 - val_mean_absolute_error: 0.2317
# Epoch 8/50
# 22/22 [==============================] - 0s 21ms/step - loss: 0.1095 - mean_absolute_error: 0.2361 - val_loss: 0.1055 - val_mean_absolute_error: 0.2296
# Epoch 9/50
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1070 - mean_absolute_error: 0.2329 - val_loss: 0.1086 - val_mean_absolute_error: 0.2324
# Epoch 10/50
# 22/22 [==============================] - 1s 27ms/step - loss: 0.1050 - mean_absolute_error: 0.2310 - val_loss: 0.1038 - val_mean_absolute_error: 0.2267
# Epoch 11/50
# 22/22 [==============================] - 1s 26ms/step - loss: 0.1058 - mean_absolute_error: 0.2332 - val_loss: 0.1036 - val_mean_absolute_error: 0.2268
# Epoch 12/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.1044 - mean_absolute_error: 0.2302 - val_loss: 0.1038 - val_mean_absolute_error: 0.2281
# Epoch 13/50
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1034 - mean_absolute_error: 0.2291 - val_loss: 0.1048 - val_mean_absolute_error: 0.2282
# Epoch 14/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.1023 - mean_absolute_error: 0.2285 - val_loss: 0.1026 - val_mean_absolute_error: 0.2253
# Epoch 15/50
# 22/22 [==============================] - 1s 22ms/step - loss: 0.1011 - mean_absolute_error: 0.2267 - val_loss: 0.1013 - val_mean_absolute_error: 0.2258
# Epoch 16/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0997 - mean_absolute_error: 0.2252 - val_loss: 0.1029 - val_mean_absolute_error: 0.2268
# Epoch 17/50
# 22/22 [==============================] - 1s 22ms/step - loss: 0.0990 - mean_absolute_error: 0.2253 - val_loss: 0.1058 - val_mean_absolute_error: 0.2331
# Epoch 18/50
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0993 - mean_absolute_error: 0.2259 - val_loss: 0.1030 - val_mean_absolute_error: 0.2283
# Epoch 19/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0978 - mean_absolute_error: 0.2246 - val_loss: 0.1021 - val_mean_absolute_error: 0.2280
# Epoch 20/50
# 22/22 [==============================] - 0s 22ms/step - loss: 0.0958 - mean_absolute_error: 0.2223 - val_loss: 0.1033 - val_mean_absolute_error: 0.2291
# Epoch 21/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0949 - mean_absolute_error: 0.2223 - val_loss: 0.1011 - val_mean_absolute_error: 0.2257
# Epoch 22/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0923 - mean_absolute_error: 0.2193 - val_loss: 0.1125 - val_mean_absolute_error: 0.2370
# Epoch 23/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0912 - mean_absolute_error: 0.2179 - val_loss: 0.1044 - val_mean_absolute_error: 0.2280
# Epoch 24/50
# 22/22 [==============================] - 1s 23ms/step - loss: 0.0899 - mean_absolute_error: 0.2172 - val_loss: 0.1036 - val_mean_absolute_error: 0.2340
# Epoch 25/50
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0888 - mean_absolute_error: 0.2161 - val_loss: 0.1145 - val_mean_absolute_error: 0.2380
# Epoch 26/50
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0864 - mean_absolute_error: 0.2136 - val_loss: 0.1070 - val_mean_absolute_error: 0.2294
# Epoch 27/50
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0853 - mean_absolute_error: 0.2136 - val_loss: 0.1040 - val_mean_absolute_error: 0.2289
# Epoch 28/50
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0835 - mean_absolute_error: 0.2104 - val_loss: 0.1094 - val_mean_absolute_error: 0.2403
# Epoch 29/50
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0850 - mean_absolute_error: 0.2140 - val_loss: 0.1150 - val_mean_absolute_error: 0.2366
# Epoch 30/50
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0820 - mean_absolute_error: 0.2094 - val_loss: 0.1120 - val_mean_absolute_error: 0.2379
# Epoch 31/50
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0794 - mean_absolute_error: 0.2069 - val_loss: 0.1124 - val_mean_absolute_error: 0.2362
# Epoch 32/50
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0774 - mean_absolute_error: 0.2040 - val_loss: 0.1140 - val_mean_absolute_error: 0.2417
# Epoch 33/50
# 22/22 [==============================] - 1s 33ms/step - loss: 0.0778 - mean_absolute_error: 0.2052 - val_loss: 0.1121 - val_mean_absolute_error: 0.2356
# Epoch 34/50
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0759 - mean_absolute_error: 0.2038 - val_loss: 0.1123 - val_mean_absolute_error: 0.2352
# Epoch 35/50
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0745 - mean_absolute_error: 0.2010 - val_loss: 0.1212 - val_mean_absolute_error: 0.2432
# Epoch 36/50
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0710 - mean_absolute_error: 0.1965 - val_loss: 0.1194 - val_mean_absolute_error: 0.2442
# Epoch 37/50
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0710 - mean_absolute_error: 0.1978 - val_loss: 0.1172 - val_mean_absolute_error: 0.2432
# Epoch 38/50
# 22/22 [==============================] - 1s 24ms/step - loss: 0.0701 - mean_absolute_error: 0.1964 - val_loss: 0.1184 - val_mean_absolute_error: 0.2439
# Epoch 39/50
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0692 - mean_absolute_error: 0.1961 - val_loss: 0.1226 - val_mean_absolute_error: 0.2474
# Epoch 40/50
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0673 - mean_absolute_error: 0.1927 - val_loss: 0.1219 - val_mean_absolute_error: 0.2457
# Epoch 41/50
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0672 - mean_absolute_error: 0.1937 - val_loss: 0.1274 - val_mean_absolute_error: 0.2510
# Epoch 42/50
# 22/22 [==============================] - 1s 26ms/step - loss: 0.0660 - mean_absolute_error: 0.1917 - val_loss: 0.1260 - val_mean_absolute_error: 0.2567
# Epoch 43/50
# 22/22 [==============================] - 1s 34ms/step - loss: 0.0688 - mean_absolute_error: 0.1966 - val_loss: 0.1375 - val_mean_absolute_error: 0.2632
# Epoch 44/50
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0631 - mean_absolute_error: 0.1875 - val_loss: 0.1236 - val_mean_absolute_error: 0.2459
# Epoch 45/50
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0611 - mean_absolute_error: 0.1854 - val_loss: 0.1271 - val_mean_absolute_error: 0.2516
# Epoch 46/50
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0601 - mean_absolute_error: 0.1837 - val_loss: 0.1283 - val_mean_absolute_error: 0.2534
# Epoch 47/50
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0586 - mean_absolute_error: 0.1815 - val_loss: 0.1299 - val_mean_absolute_error: 0.2571
# Epoch 48/50
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0584 - mean_absolute_error: 0.1816 - val_loss: 0.1341 - val_mean_absolute_error: 0.2612
# Epoch 49/50
# 22/22 [==============================] - 1s 27ms/step - loss: 0.0553 - mean_absolute_error: 0.1768 - val_loss: 0.1320 - val_mean_absolute_error: 0.2588
# Epoch 50/50
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0544 - mean_absolute_error: 0.1765 - val_loss: 0.1338 - val_mean_absolute_error: 0.2638

# %%
### Get prediction on the test data and convert the result back to stock price (i.e., de-normalization)
from sklearn.metrics import mean_squared_error
# Get prediction on the test data
y_pred_norm_1 = model1.predict(X_test_norm_1)
y_pred_norm_1[1]
# print("MSE on the test set: ", mean_squared_error(y_test_norm, y_pred_norm))
# Out:
# 27/27 [==============================] - 0s 5ms/step
# array([0.8197593 , 0.9234539 , 0.87084484, 0.9303611 , 0.9349676 ,
#        0.9712728 , 0.9788134 ], dtype=float32)

# %%
y_pred_norm_1.shape
# Out:
# (859, 7)

# %%
# Rescale the predicted prices to the original range
y_pred_denorm_1 = y_pred_norm_1
for i in range(0, len(y_pred_denorm_1)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(X_test_1[i])
    max_feature = np.max(X_test_1[i])
    y_pred_denorm_1[i] = y_pred_norm_1[i] * (max_feature - min_feature) + min_feature

# %%
# Get the latest 30-day data to predict for the prices of the next 7 days in the future
latest_30_days = df.iloc[-30:, 0].values.reshape(1, window_size, 1)

# Normalize the latest 30-day data
latest_30_days_norm = latest_30_days.copy()
for i in range(0, len(latest_30_days_norm)):
    min_feature = np.min(latest_30_days[i])
    max_feature = np.max(latest_30_days[i])
    latest_30_days_norm[i] = (latest_30_days[i] - min_feature) / (max_feature - min_feature)
predicted_prices_norm = model1.predict(latest_30_days_norm)

# Use the trained model to predict the prices for the next 7 days
predicted_prices_denorm = predicted_prices_norm
for i in range(0, len(predicted_prices_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(latest_30_days[i])
    max_feature = np.max(latest_30_days[i])
    predicted_prices_denorm[i] = predicted_prices_norm[i] * (max_feature - min_feature) + min_feature

# Print the predicted prices for the next 7 days
print(predicted_prices_denorm)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# [[13.667672  13.5769615 13.390155  13.242351  13.2254095 13.1393385
#   13.186017 ]]

# %%
predicted_prices_denorm = predicted_prices_denorm.flatten()
# Select the latest 2 years from the test_dates
test_dates_latest_2years = [d for d in test_dates if d >= test_dates[-1] - datetime.timedelta(days=100)]

# Create a list of the next 7 dates
next_7_dates = [test_dates_latest_2years[-1] + datetime.timedelta(days=x) for x in range(1, 8)]

# Plot the predicted prices in the next 7 days
plt.plot(next_7_dates, predicted_prices_denorm, label = 'Predicted Price for a week in the future')
plt.plot(test_dates_latest_2years, y_test[-len(test_dates_latest_2years):], label = 'Current Real Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
