# %% [markdown]
# # Getting started with basic CNN model

# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('..')

# %%
df_AAL = pd.read_csv('../1. data_nasdaq/data_nasdaq_csv/AAL.csv')
df_AAL
# Out:
#             Date        Low       Open    Volume       High      Close  \
# 0     27-09-2005  19.100000  21.049999    961200  21.400000  19.299999
# 1     28-09-2005  19.200001  19.299999   5747900  20.530001  20.500000
# 2     29-09-2005  20.100000  20.400000   1078200  20.580000  20.209999
# 3     30-09-2005  20.180000  20.260000   3123300  21.049999  21.010000
# 4     03-10-2005  20.900000  20.900000   1057900  21.750000  21.500000
# ...          ...        ...        ...       ...        ...        ...
# 4328  06-12-2022  14.000000  14.140000  20781500  14.340000  14.330000
# 4329  07-12-2022  13.530000  14.240000  28161400  14.240000  13.550000
# 4330  08-12-2022  13.380000  13.650000  25300900  13.800000  13.600000
# 4331  09-12-2022  13.420000  13.520000  18489800  13.660000  13.530000
# 4332  12-12-2022  13.450000  13.490000   8048550  13.930000  13.915000
#
#       Adjusted Close
# 0          18.194910
# 1          19.326204
# 2          19.052805
# 3          19.807001
# 4          20.268940
# ...              ...
# 4328       14.330000
# 4329       13.550000
# 4330       13.600000
# 4331       13.530000
# 4332       13.915000
#
# [4333 rows x 7 columns]

# %%
df = df_AAL.drop(columns = ['Low', 'High', 'Open', 'Adjusted Close', 'Volume'], axis = 1)

# %%
import datetime
def str_to_datetime(s):
    try:
        split = s.split('-')
        day, month, year = int(split[0]), int(split[1]), int(split[2])
        return datetime.datetime(day=day, month=month, year=year)
    except ValueError:
        print(f"Invalid date string: {s}")
        return None
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# 0      2005-09-27
# 1      2005-09-28
# 2      2005-09-29
# 3      2005-09-30
# 4      2005-10-03
#           ...
# 4328   2022-12-06
# 4329   2022-12-07
# 4330   2022-12-08
# 4331   2022-12-09
# 4332   2022-12-12
# Name: Date, Length: 4333, dtype: datetime64[ns]

# %%
# Set date as the index
df.index = df.pop('Date')

# %%
plt.rcParams['figure.figsize'] = (18, 12)

def price(x):
    """
    format the coords message box
    :param x: data to be formatted
    :return: formatted data
    """
    return '$%1.2f' % x

fig, ax = plt.subplots()
ax.plot(df.index, df['Close'], '#0A7388')
ax.format_ydata = price
# Add labels
plt.ylabel("Price USD")
plt.xlabel("Date")

plt.show()

# %%
### Split the dataset into time windows to get data samples.

# df = data_appl
X_data = []
y_data = []
dates = []
window_size = 30 # Time window for data feature (size of 'number of days') to learn.

# Only get the open price (index 2 in the data frame)
for i in range(1, len(df) - window_size - 1):
    first = df.iloc[i, 0]
    data_feature = []
    data_label = []
    
    # Get a window_size time frame for data feature
    for j in range(window_size):
        data_feature.append(df.iloc[i + j, 0])
        
    # Next value is the label (price of the next day) to be predicted
    data_label.append(df.iloc[i + window_size, 0])
    
    # Append new data sample (feature and label) to X_data and y_data
    X_data.append(np.array(data_feature).reshape(window_size, 1))
    y_data.append(np.array(data_label))
    dates.append(df.iloc[i + window_size, :].name)

# %%
len(X_data), len(y_data), len(dates)
# Out:
# (4301, 4301, 4301)

# %%
from helper_functions import data_preprocessing as pp
X_train, y_train, X_val, y_val, X_test, y_test = pp.split_dataset(X_data, y_data, 0.2)

# %%
train_dates = dates[:X_train.shape[0]]
val_dates = dates[X_train.shape[0]:(X_train.shape[0]+X_val.shape[0])]
test_dates = dates[-X_test.shape[0]:]

# %%
# Visualize the training, validation and test set
fig, ax = plt.subplots(figsize = (16,8))
df_plot = df['Close']
df_plot = df_plot.reset_index(drop=False)
plt.plot(train_dates, y_train)
plt.plot(val_dates, y_val)
plt.plot(test_dates, y_test)
plt.xlabel('Year')
plt.ylabel('Close price in $')
plt.legend(['Train', 'Validation', 'Test'])

# Add vertical lines to separate training, validation, and test sets
plt.axvline(x=train_dates[-1], color='k', linestyle='--')
plt.axvline(x=val_dates[-1], color='k', linestyle='--')

plt.show()

# %%
# Normalize data
X_train_norm, y_train_norm = pp.normalize_data(X_train, y_train)
X_val_norm, y_val_norm = pp.normalize_data(X_val, y_val)
X_test_norm, y_test_norm = pp.normalize_data(X_test, y_test)

# %%
### Create and train the model

# Import libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, LSTM, Dropout, Activation

# Build the model architecture
model = Sequential()
model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(window_size, 1), padding='same'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(1)) # By default: activation='linear', i.e., passing through f(x) = x

# Compile and train the model with Mean Squared Error loss function
model.compile(optimizer= Adam(learning_rate=0.001), 
              loss='mse', 
              metrics=['mean_absolute_error'])
model_training = model.fit(X_train_norm, y_train_norm, validation_data=(X_val_norm,y_val_norm), epochs=50, batch_size=32)
# Out:
# 2023-05-24 15:34:03.395267: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 86/86 [==============================] - 4s 18ms/step - loss: 0.0903 - mean_absolute_error: 0.2284 - val_loss: 0.0389 - val_mean_absolute_error: 0.1433
# Epoch 2/50
# 86/86 [==============================] - 1s 9ms/step - loss: 0.0321 - mean_absolute_error: 0.1312 - val_loss: 0.0316 - val_mean_absolute_error: 0.1357
# Epoch 3/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0279 - mean_absolute_error: 0.1214 - val_loss: 0.0262 - val_mean_absolute_error: 0.1164
# Epoch 4/50
# 86/86 [==============================] - 1s 17ms/step - loss: 0.0265 - mean_absolute_error: 0.1181 - val_loss: 0.0261 - val_mean_absolute_error: 0.1149
# Epoch 5/50
# 86/86 [==============================] - 2s 25ms/step - loss: 0.0257 - mean_absolute_error: 0.1163 - val_loss: 0.0247 - val_mean_absolute_error: 0.1137
# Epoch 6/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0249 - mean_absolute_error: 0.1141 - val_loss: 0.0236 - val_mean_absolute_error: 0.1117
# Epoch 7/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0247 - mean_absolute_error: 0.1151 - val_loss: 0.0301 - val_mean_absolute_error: 0.1298
# Epoch 8/50
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0241 - mean_absolute_error: 0.1129 - val_loss: 0.0234 - val_mean_absolute_error: 0.1103
# Epoch 9/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.1114 - val_loss: 0.0232 - val_mean_absolute_error: 0.1089
# Epoch 10/50
# 86/86 [==============================] - 1s 17ms/step - loss: 0.0241 - mean_absolute_error: 0.1137 - val_loss: 0.0248 - val_mean_absolute_error: 0.1164
# Epoch 11/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0243 - mean_absolute_error: 0.1134 - val_loss: 0.0232 - val_mean_absolute_error: 0.1104
# Epoch 12/50
# 86/86 [==============================] - 2s 19ms/step - loss: 0.0219 - mean_absolute_error: 0.1074 - val_loss: 0.0242 - val_mean_absolute_error: 0.1126
# Epoch 13/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0221 - mean_absolute_error: 0.1091 - val_loss: 0.0256 - val_mean_absolute_error: 0.1175
# Epoch 14/50
# 86/86 [==============================] - 2s 19ms/step - loss: 0.0214 - mean_absolute_error: 0.1072 - val_loss: 0.0228 - val_mean_absolute_error: 0.1094
# Epoch 15/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0213 - mean_absolute_error: 0.1069 - val_loss: 0.0247 - val_mean_absolute_error: 0.1154
# Epoch 16/50
# 86/86 [==============================] - 2s 18ms/step - loss: 0.0212 - mean_absolute_error: 0.1074 - val_loss: 0.0234 - val_mean_absolute_error: 0.1111
# Epoch 17/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0211 - mean_absolute_error: 0.1079 - val_loss: 0.0270 - val_mean_absolute_error: 0.1216
# Epoch 18/50
# 86/86 [==============================] - 2s 18ms/step - loss: 0.0197 - mean_absolute_error: 0.1033 - val_loss: 0.0268 - val_mean_absolute_error: 0.1224
# Epoch 19/50
# 86/86 [==============================] - 2s 18ms/step - loss: 0.0191 - mean_absolute_error: 0.1026 - val_loss: 0.0250 - val_mean_absolute_error: 0.1160
# Epoch 20/50
# 86/86 [==============================] - 2s 21ms/step - loss: 0.0190 - mean_absolute_error: 0.1025 - val_loss: 0.0259 - val_mean_absolute_error: 0.1181
# Epoch 21/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0186 - mean_absolute_error: 0.1014 - val_loss: 0.0265 - val_mean_absolute_error: 0.1181
# Epoch 22/50
# 86/86 [==============================] - 1s 17ms/step - loss: 0.0177 - mean_absolute_error: 0.0992 - val_loss: 0.0264 - val_mean_absolute_error: 0.1197
# Epoch 23/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0173 - mean_absolute_error: 0.0990 - val_loss: 0.0257 - val_mean_absolute_error: 0.1157
# Epoch 24/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0171 - mean_absolute_error: 0.0984 - val_loss: 0.0265 - val_mean_absolute_error: 0.1198
# Epoch 25/50
# 86/86 [==============================] - 2s 19ms/step - loss: 0.0160 - mean_absolute_error: 0.0951 - val_loss: 0.0264 - val_mean_absolute_error: 0.1188
# Epoch 26/50
# 86/86 [==============================] - 2s 18ms/step - loss: 0.0160 - mean_absolute_error: 0.0949 - val_loss: 0.0271 - val_mean_absolute_error: 0.1200
# Epoch 27/50
# 86/86 [==============================] - 2s 18ms/step - loss: 0.0153 - mean_absolute_error: 0.0928 - val_loss: 0.0277 - val_mean_absolute_error: 0.1205
# Epoch 28/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0148 - mean_absolute_error: 0.0924 - val_loss: 0.0287 - val_mean_absolute_error: 0.1245
# Epoch 29/50
# 86/86 [==============================] - 2s 18ms/step - loss: 0.0151 - mean_absolute_error: 0.0931 - val_loss: 0.0282 - val_mean_absolute_error: 0.1226
# Epoch 30/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0154 - mean_absolute_error: 0.0945 - val_loss: 0.0307 - val_mean_absolute_error: 0.1284
# Epoch 31/50
# 86/86 [==============================] - 2s 19ms/step - loss: 0.0137 - mean_absolute_error: 0.0889 - val_loss: 0.0316 - val_mean_absolute_error: 0.1320
# Epoch 32/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0136 - mean_absolute_error: 0.0887 - val_loss: 0.0310 - val_mean_absolute_error: 0.1297
# Epoch 33/50
# 86/86 [==============================] - 2s 19ms/step - loss: 0.0124 - mean_absolute_error: 0.0850 - val_loss: 0.0319 - val_mean_absolute_error: 0.1301
# Epoch 34/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0128 - mean_absolute_error: 0.0860 - val_loss: 0.0320 - val_mean_absolute_error: 0.1335
# Epoch 35/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0118 - mean_absolute_error: 0.0824 - val_loss: 0.0333 - val_mean_absolute_error: 0.1379
# Epoch 36/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0115 - mean_absolute_error: 0.0818 - val_loss: 0.0298 - val_mean_absolute_error: 0.1254
# Epoch 37/50
# 86/86 [==============================] - 1s 12ms/step - loss: 0.0106 - mean_absolute_error: 0.0782 - val_loss: 0.0322 - val_mean_absolute_error: 0.1344
# Epoch 38/50
# 86/86 [==============================] - 2s 21ms/step - loss: 0.0109 - mean_absolute_error: 0.0791 - val_loss: 0.0315 - val_mean_absolute_error: 0.1282
# Epoch 39/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0104 - mean_absolute_error: 0.0777 - val_loss: 0.0319 - val_mean_absolute_error: 0.1299
# Epoch 40/50
# 86/86 [==============================] - 2s 18ms/step - loss: 0.0101 - mean_absolute_error: 0.0762 - val_loss: 0.0326 - val_mean_absolute_error: 0.1326
# Epoch 41/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0096 - mean_absolute_error: 0.0752 - val_loss: 0.0329 - val_mean_absolute_error: 0.1315
# Epoch 42/50
# 86/86 [==============================] - 2s 19ms/step - loss: 0.0088 - mean_absolute_error: 0.0717 - val_loss: 0.0320 - val_mean_absolute_error: 0.1309
# Epoch 43/50
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0085 - mean_absolute_error: 0.0699 - val_loss: 0.0333 - val_mean_absolute_error: 0.1335
# Epoch 44/50
# 86/86 [==============================] - 2s 23ms/step - loss: 0.0081 - mean_absolute_error: 0.0682 - val_loss: 0.0355 - val_mean_absolute_error: 0.1390
# Epoch 45/50
# 86/86 [==============================] - 2s 23ms/step - loss: 0.0077 - mean_absolute_error: 0.0669 - val_loss: 0.0342 - val_mean_absolute_error: 0.1343
# Epoch 46/50
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0073 - mean_absolute_error: 0.0647 - val_loss: 0.0365 - val_mean_absolute_error: 0.1415
# Epoch 47/50
# 86/86 [==============================] - 2s 21ms/step - loss: 0.0070 - mean_absolute_error: 0.0637 - val_loss: 0.0344 - val_mean_absolute_error: 0.1364
# Epoch 48/50
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0072 - mean_absolute_error: 0.0657 - val_loss: 0.0344 - val_mean_absolute_error: 0.1344
# Epoch 49/50
# 86/86 [==============================] - 2s 26ms/step - loss: 0.0065 - mean_absolute_error: 0.0613 - val_loss: 0.0359 - val_mean_absolute_error: 0.1379
# Epoch 50/50
# 86/86 [==============================] - 2s 22ms/step - loss: 0.0067 - mean_absolute_error: 0.0628 - val_loss: 0.0352 - val_mean_absolute_error: 0.1372

# %%
### Get prediction on the test data and convert the result back to stock price (i.e., de-normalization)
from sklearn.metrics import mean_squared_error

# Get prediction on the test data
y_pred_norm = model.predict(X_test_norm)
print("MSE on the test set: ", mean_squared_error(y_pred_norm, y_test_norm))
# Out:
# 27/27 [==============================] - 1s 4ms/step
# MSE on the test set:  0.04631689801688411

# %%
y_pred_norm[1]
# Out:
# array([1.0938983], dtype=float32)

# %%
train_predictions = model.predict(X_train_norm).flatten()

plt.plot(train_dates, train_predictions)
plt.plot(train_dates, y_train_norm)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 86/86 [==============================] - 1s 6ms/step

# %%
val_predictions = model.predict(X_val_norm).flatten()

plt.plot(val_dates, val_predictions)
plt.plot(val_dates, y_val_norm)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 22/22 [==============================] - 0s 6ms/step

# %%
test_predictions = model.predict(X_test_norm).flatten()

plt.plot(test_dates, test_predictions)
plt.plot(test_dates, y_test_norm)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 27/27 [==============================] - 0s 8ms/step

# %%
# Convert the result back to stock price (i.e., de-normalization) for visualization purpose
y_pred_denorm = y_pred_norm
for i in range(0, len(y_pred_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(X_test[i])
    max_feature = np.max(X_test[i])
    y_pred_denorm[i] = y_pred_norm[i] * (max_feature - min_feature) + min_feature

# %%
plt.plot(test_dates, y_pred_denorm)
plt.plot(test_dates, y_test)

plt.xlabel('Year', fontsize = 20)
plt.ylabel('Close price in $', fontsize = 20)
plt.legend(['Prediction', 'Real Price'], fontsize = 20)
plt.grid() # Add grid
plt.savefig('CNN_result_AAL.png')
plt.show()

# %%
# from copy import deepcopy

# recursive_predictions = []
# recursive_dates = np.concatenate([val_dates, test_dates])

# for target_date in recursive_dates:
#     last_window = deepcopy(X_train_norm[-1])
#     next_prediction = model.predict(np.array([last_window])).flatten()
#     recursive_predictions.append(next_prediction)
#     last_window[-1] = next_prediction

# %%
X_data_1 = []
y_data_1 = []
dates = []
window_size = 30 # Time window for data feature (size of 'number of days') to learn.
forecast_days = 7 # Number of days to forecast

# Only get the open price (index 2 in the data frame)
for i in range(1, len(df) - window_size - forecast_days):
    first = df.iloc[i, 0]
    data_features = []
    data_labels = []
    
    # Get a window_size time frame for data feature
    for j in range(window_size):
        data_features.append(df.iloc[i + j, 0])
        
    # Next 7 values are the label (prices of the next 7 days) to be predicted
    for k in range(forecast_days):
        data_labels.append(df.iloc[i + window_size + k, 0])
    
    # Append new data sample (feature and label) to X_data and y_data
    X_data_1.append(np.array(data_features).reshape(window_size, 1))
    y_data_1.append(np.array(data_labels))
    dates.append(df.iloc[i + window_size, :].name)

# Normalize data
X_train_norm_1, y_train_norm_1 = pp.normalize_data(X_train_1, y_train_1)
X_val_norm_1, y_val_norm_1 = pp.normalize_data(X_val_1, y_val_1)
X_test_norm_1, y_test_norm_1 = pp.normalize_data(X_test_1, y_test_1)

# %%
X_train_1[0], y_train_1[0]
# Out:
# (array([[20.5       ],
#         [20.20999908],
#         [21.01000023],
#         [21.5       ],
#         [22.15999985],
#         [22.20000076],
#         [22.57999992],
#         [22.14999962],
#         [22.20999908],
#         [21.97999954],
#         [21.76000023],
#         [21.70999908],
#         [22.27000046],
#         [22.07999992],
#         [21.48999977],
#         [21.37999916],
#         [21.02000046],
#         [21.95999908],
#         [22.30999947],
#         [22.        ],
#         [22.31999969],
#         [22.55999947],
#         [23.89999962],
#         [24.68000031],
#         [25.02000046],
#         [27.54999924],
#         [27.87000084],
#         [28.79999924],
#         [28.93000031],
#         [29.43000031]]),
#  array([31.29999924, 32.79999924, 33.34999847, 33.75      , 33.88000107,
#         33.59999847, 34.31999969]))

# %%
X_train_norm_1.shape, y_train_norm_1.shape
# Out:
# ((2748, 30, 1), (2748, 7))

# %%
X_test_norm_1.shape, y_test_norm_1.shape
# Out:
# ((859, 30, 1), (859, 7))

# %%
# Build the model architecture
model1 = Sequential()
model1.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=(window_size, 1), padding='same'))
model1.add(MaxPooling1D(pool_size=2))
model1.add(Conv1D(128, kernel_size=3, activation='relu', padding='same'))
model1.add(MaxPooling1D(2))
model1.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
model1.add(MaxPooling1D(2))
model1.add(Flatten())
model1.add(Dense(100, activation='relu'))
model1.add(Dense(7)) # By default: activation='linear', i.e., passing through f(x) = x

# Compile and train the model with Mean Squared Error loss function
model1.compile(optimizer= Adam(learning_rate=0.001), 
              loss='mse', 
              metrics=['mean_absolute_error'])
model_training1 = model1.fit(X_train_norm_1, y_train_norm_1, validation_data=(X_val_norm_1,y_val_norm_1), epochs=50, batch_size=128)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 6s 134ms/step - loss: 0.3214 - mean_absolute_error: 0.4562 - val_loss: 0.2296 - val_mean_absolute_error: 0.3752
# Epoch 2/50
# 22/22 [==============================] - 1s 43ms/step - loss: 0.1932 - mean_absolute_error: 0.3436 - val_loss: 0.1566 - val_mean_absolute_error: 0.2886
# Epoch 3/50
# 22/22 [==============================] - 1s 48ms/step - loss: 0.1360 - mean_absolute_error: 0.2737 - val_loss: 0.1237 - val_mean_absolute_error: 0.2461
# Epoch 4/50
# 22/22 [==============================] - 1s 37ms/step - loss: 0.1173 - mean_absolute_error: 0.2476 - val_loss: 0.1201 - val_mean_absolute_error: 0.2453
# Epoch 5/50
# 22/22 [==============================] - 1s 38ms/step - loss: 0.1103 - mean_absolute_error: 0.2374 - val_loss: 0.1109 - val_mean_absolute_error: 0.2333
# Epoch 6/50
# 22/22 [==============================] - 1s 47ms/step - loss: 0.1080 - mean_absolute_error: 0.2341 - val_loss: 0.1087 - val_mean_absolute_error: 0.2306
# Epoch 7/50
# 22/22 [==============================] - 1s 38ms/step - loss: 0.1069 - mean_absolute_error: 0.2328 - val_loss: 0.1069 - val_mean_absolute_error: 0.2304
# Epoch 8/50
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1074 - mean_absolute_error: 0.2350 - val_loss: 0.1064 - val_mean_absolute_error: 0.2315
# Epoch 9/50
# 22/22 [==============================] - 1s 48ms/step - loss: 0.1068 - mean_absolute_error: 0.2342 - val_loss: 0.1070 - val_mean_absolute_error: 0.2310
# Epoch 10/50
# 22/22 [==============================] - 1s 40ms/step - loss: 0.1039 - mean_absolute_error: 0.2295 - val_loss: 0.1061 - val_mean_absolute_error: 0.2293
# Epoch 11/50
# 22/22 [==============================] - 1s 29ms/step - loss: 0.1033 - mean_absolute_error: 0.2286 - val_loss: 0.1062 - val_mean_absolute_error: 0.2288
# Epoch 12/50
# 22/22 [==============================] - 1s 49ms/step - loss: 0.1025 - mean_absolute_error: 0.2281 - val_loss: 0.1100 - val_mean_absolute_error: 0.2341
# Epoch 13/50
# 22/22 [==============================] - 1s 52ms/step - loss: 0.1020 - mean_absolute_error: 0.2282 - val_loss: 0.1051 - val_mean_absolute_error: 0.2296
# Epoch 14/50
# 22/22 [==============================] - 1s 54ms/step - loss: 0.1008 - mean_absolute_error: 0.2263 - val_loss: 0.1055 - val_mean_absolute_error: 0.2324
# Epoch 15/50
# 22/22 [==============================] - 2s 72ms/step - loss: 0.1002 - mean_absolute_error: 0.2266 - val_loss: 0.1038 - val_mean_absolute_error: 0.2300
# Epoch 16/50
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0999 - mean_absolute_error: 0.2261 - val_loss: 0.1050 - val_mean_absolute_error: 0.2323
# Epoch 17/50
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0974 - mean_absolute_error: 0.2236 - val_loss: 0.1059 - val_mean_absolute_error: 0.2294
# Epoch 18/50
# 22/22 [==============================] - 1s 65ms/step - loss: 0.0971 - mean_absolute_error: 0.2235 - val_loss: 0.1031 - val_mean_absolute_error: 0.2288
# Epoch 19/50
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0956 - mean_absolute_error: 0.2216 - val_loss: 0.1098 - val_mean_absolute_error: 0.2369
# Epoch 20/50
# 22/22 [==============================] - 2s 77ms/step - loss: 0.0985 - mean_absolute_error: 0.2268 - val_loss: 0.1023 - val_mean_absolute_error: 0.2288
# Epoch 21/50
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0933 - mean_absolute_error: 0.2199 - val_loss: 0.1096 - val_mean_absolute_error: 0.2366
# Epoch 22/50
# 22/22 [==============================] - 2s 89ms/step - loss: 0.0928 - mean_absolute_error: 0.2203 - val_loss: 0.1081 - val_mean_absolute_error: 0.2340
# Epoch 23/50
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0918 - mean_absolute_error: 0.2190 - val_loss: 0.1126 - val_mean_absolute_error: 0.2376
# Epoch 24/50
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0911 - mean_absolute_error: 0.2195 - val_loss: 0.1055 - val_mean_absolute_error: 0.2307
# Epoch 25/50
# 22/22 [==============================] - 1s 67ms/step - loss: 0.0887 - mean_absolute_error: 0.2158 - val_loss: 0.1073 - val_mean_absolute_error: 0.2311
# Epoch 26/50
# 22/22 [==============================] - 1s 48ms/step - loss: 0.0863 - mean_absolute_error: 0.2134 - val_loss: 0.1073 - val_mean_absolute_error: 0.2330
# Epoch 27/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0857 - mean_absolute_error: 0.2130 - val_loss: 0.1080 - val_mean_absolute_error: 0.2323
# Epoch 28/50
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0855 - mean_absolute_error: 0.2133 - val_loss: 0.1097 - val_mean_absolute_error: 0.2383
# Epoch 29/50
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0829 - mean_absolute_error: 0.2100 - val_loss: 0.1112 - val_mean_absolute_error: 0.2350
# Epoch 30/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0813 - mean_absolute_error: 0.2088 - val_loss: 0.1095 - val_mean_absolute_error: 0.2369
# Epoch 31/50
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0799 - mean_absolute_error: 0.2067 - val_loss: 0.1123 - val_mean_absolute_error: 0.2385
# Epoch 32/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0781 - mean_absolute_error: 0.2045 - val_loss: 0.1095 - val_mean_absolute_error: 0.2339
# Epoch 33/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0768 - mean_absolute_error: 0.2035 - val_loss: 0.1146 - val_mean_absolute_error: 0.2394
# Epoch 34/50
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0752 - mean_absolute_error: 0.2025 - val_loss: 0.1164 - val_mean_absolute_error: 0.2414
# Epoch 35/50
# 22/22 [==============================] - 1s 48ms/step - loss: 0.0743 - mean_absolute_error: 0.2008 - val_loss: 0.1219 - val_mean_absolute_error: 0.2480
# Epoch 36/50
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0729 - mean_absolute_error: 0.1997 - val_loss: 0.1233 - val_mean_absolute_error: 0.2465
# Epoch 37/50
# 22/22 [==============================] - 1s 36ms/step - loss: 0.0719 - mean_absolute_error: 0.1984 - val_loss: 0.1402 - val_mean_absolute_error: 0.2668
# Epoch 38/50
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0758 - mean_absolute_error: 0.2043 - val_loss: 0.1407 - val_mean_absolute_error: 0.2647
# Epoch 39/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0718 - mean_absolute_error: 0.1996 - val_loss: 0.1247 - val_mean_absolute_error: 0.2484
# Epoch 40/50
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0683 - mean_absolute_error: 0.1940 - val_loss: 0.1216 - val_mean_absolute_error: 0.2457
# Epoch 41/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0642 - mean_absolute_error: 0.1881 - val_loss: 0.1301 - val_mean_absolute_error: 0.2530
# Epoch 42/50
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0628 - mean_absolute_error: 0.1871 - val_loss: 0.1228 - val_mean_absolute_error: 0.2447
# Epoch 43/50
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0643 - mean_absolute_error: 0.1905 - val_loss: 0.1266 - val_mean_absolute_error: 0.2546
# Epoch 44/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0650 - mean_absolute_error: 0.1920 - val_loss: 0.1295 - val_mean_absolute_error: 0.2518
# Epoch 45/50
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0632 - mean_absolute_error: 0.1880 - val_loss: 0.1348 - val_mean_absolute_error: 0.2565
# Epoch 46/50
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0592 - mean_absolute_error: 0.1822 - val_loss: 0.1314 - val_mean_absolute_error: 0.2527
# Epoch 47/50
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0598 - mean_absolute_error: 0.1842 - val_loss: 0.1325 - val_mean_absolute_error: 0.2531
# Epoch 48/50
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0572 - mean_absolute_error: 0.1797 - val_loss: 0.1363 - val_mean_absolute_error: 0.2574
# Epoch 49/50
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0561 - mean_absolute_error: 0.1795 - val_loss: 0.1315 - val_mean_absolute_error: 0.2527
# Epoch 50/50
# 22/22 [==============================] - 1s 55ms/step - loss: 0.0544 - mean_absolute_error: 0.1760 - val_loss: 0.1322 - val_mean_absolute_error: 0.2546

# %%
### Get prediction on the test data and convert the result back to stock price (i.e., de-normalization)
from sklearn.metrics import mean_squared_error
# Get prediction on the test data
y_pred_norm_1 = model1.predict(X_test_norm_1)
y_pred_norm_1[1]
print("MSE on the test set: ", mean_squared_error(y_test_norm_1.flatten(), y_pred_norm_1.flatten()))
# Out:
# 27/27 [==============================] - 0s 4ms/step
# MSE on the test set:  0.17305438177258042

# %%
# Rescale the predicted prices to the original range
y_pred_denorm_1 = y_pred_norm_1
for i in range(0, len(y_pred_denorm_1)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(X_test_1[i])
    max_feature = np.max(X_test_1[i])
    y_pred_denorm_1[i] = y_pred_norm_1[i] * (max_feature - min_feature) + min_feature

# %%
len(y_pred_denorm_1)
# Out:
# 859

# %%
X_train_1, y_train_1, X_val_1, y_val_1, X_test_1, y_test_1 = pp.split_dataset(X_data_1, y_data_1, 0.2)
train_dates_1 = dates[:X_train_1.shape[0]]
val_dates_1 = dates[X_train_1.shape[0]:(X_train_1.shape[0]+X_val_1.shape[0])]
test_dates_1 = dates[-X_test_1.shape[0]:]

# %%
y_pred_denorm_1
# Out:
# array([[32.847458 , 33.321865 , 33.513924 , ..., 34.030914 , 33.97813  ,
#         34.050114 ],
#        [32.524384 , 32.75085  , 32.997303 , ..., 32.80727  , 32.886784 ,
#         32.795044 ],
#        [33.131584 , 33.284958 , 33.265884 , ..., 33.07032  , 33.095005 ,
#         33.113235 ],
#        ...,
#        [13.813657 , 13.789642 , 13.813915 , ..., 14.043356 , 14.072104 ,
#         14.113352 ],
#        [13.948025 , 13.941195 , 13.903383 , ..., 14.080954 , 14.204246 ,
#         14.335132 ],
#        [14.4137335, 14.499692 , 14.599136 , ..., 14.922911 , 15.115133 ,
#         15.166378 ]], dtype=float32)

# %%
y_test_1[0]
# Out:
# array([32.36000061, 32.93999863, 33.02999878, 33.77999878, 33.61000061,
#        34.22000122, 33.25999832])

# %%
y_pred_first = [lst[0] for lst in y_pred_denorm_1]
y_test_first = [lst[0] for lst in y_test_1]

plt.plot(test_dates_1, y_pred_first)
plt.plot(test_dates_1, y_test_first)

plt.xlabel('Year', fontsize = 20)
plt.ylabel('Close price in $', fontsize = 20)
plt.legend(['Prediction', 'Real Price'], fontsize = 20)
plt.grid() # Add grid
plt.savefig('ALL_CNN_7d.png')
plt.show()

# %%
# Get the latest 30-day data to predict for the prices of the next 7 days in the future
latest_30_days = df.iloc[-30:, 0].values.reshape(1, window_size, 1)

# Normalize the latest 30-day data
latest_30_days_norm = latest_30_days.copy()
for i in range(0, len(latest_30_days_norm)):
    min_feature = np.min(latest_30_days[i])
    max_feature = np.max(latest_30_days[i])
    latest_30_days_norm[i] = (latest_30_days[i] - min_feature) / (max_feature - min_feature)
predicted_prices_norm = model1.predict(latest_30_days_norm)

# Use the trained model to predict the prices for the next 7 days
predicted_prices_denorm = predicted_prices_norm
for i in range(0, len(predicted_prices_denorm)): # denorm_x = norm_x * (max(x) - min(x)) + min(x)
    min_feature = np.min(latest_30_days[i])
    max_feature = np.max(latest_30_days[i])
    predicted_prices_denorm[i] = predicted_prices_norm[i] * (max_feature - min_feature) + min_feature

# Print the predicted prices for the next 7 days
print(predicted_prices_denorm)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# [[13.797889  13.772014  13.7226715 13.660781  13.596505  13.533294
#   13.661561 ]]

# %%
predicted_prices_denorm = predicted_prices_denorm.flatten()
# Select the latest 100 days from the test_dates

test_dates_latest_2years = [d for d in test_dates if d >= test_dates[-1] - datetime.timedelta(days=200)]

# Create a list of the next 7 dates
next_7_dates = [test_dates_latest_2years[-1] + datetime.timedelta(days=x) for x in range(1, 8)]

# Plot the predicted prices in the next 7 days
plt.plot(next_7_dates, predicted_prices_denorm, label = 'Predicted Price for a week in the future')
plt.plot(test_dates_latest_2years, y_test[-len(test_dates_latest_2years):], label = 'Current Real Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
